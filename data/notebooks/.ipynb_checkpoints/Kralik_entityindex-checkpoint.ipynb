# %% [markdown]
# # **1. Libaries and files**

# %%
#Importing libraries
import os
import glob
import re
import json
from bs4 import BeautifulSoup, Tag, NavigableString
import xml.etree.ElementTree as ET
from xml.dom import minidom
from xml.etree.ElementTree import Element
from xml.etree.ElementTree import SubElement
import pandas as pd
from lxml import etree

# %%
#Change accordingly
file_path_index="C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/tei/Index/index_person_place_org.xml"

# %% [markdown]
# # **2. Creating csv with index**

# %%
#Accessing index
tree = etree.parse(file_path_index)
root = tree.getroot()

# %%
# Define the TEI namespace
ns = {'tei': 'http://www.tei-c.org/ns/1.0'}

# %% [markdown]
# ## **2.1. Index person**

# %%
#Partly created with the help of u:ai
# Extract <person> elements
persons = root.xpath('//tei:listPerson/tei:person', namespaces=ns)
print(f"Number of <person> elements found: {len(persons)}")

# Extract data
data = []
for person in persons:
    person_data = {}
    # Extract xml:id
    person_data['ID'] = person.get('{http://www.w3.org/XML/1998/namespace}id')
    
    # Extract forename
    forename = person.find('tei:persName/tei:forename', namespaces=ns)
    person_data['forename'] = forename.text if forename is not None else None
    
    # Extract surname
    surname = person.find('tei:persName/tei:surname', namespaces=ns)
    person_data['surname'] = surname.text if surname is not None else None

    # Extract surname maiden
    surname_maiden = person.find('tei:persName/tei:surname[@type="maiden"]', namespaces=ns)
    person_data['surname maiden']= surname_maiden.text if surname_maiden is not None else None
    
    # Extract occupations (can be multiple)
    occupations = person.findall('tei:occupation', namespaces=ns)
    occupation_data = []
    for occ in occupations:
        # Get the main text of the occupation
        occ_text = occ.text.strip() if occ.text else ""
        
        # Check for nested <orgName> elements
        org_name = occ.find('tei:orgName', namespaces=ns)
        if org_name is not None:
            org_name_text = org_name.text.strip() if org_name.text else ""
            # Combine the occupation text with the organization name
            occ_text += f" {org_name_text}"
        # Add the processed occupation to the list
        occupation_data.append(occ_text)
        # Join all occupations into a single string
        person_data['occupations'] = "; ".join(occupation_data)

    # Extract affiliations (can be multiple)
    affiliations = person.findall('tei:affiliation', namespaces=ns)

    affiliations_data=[]
    for aff in affiliations:
        # Get the main text of the occupation
        aff_text = aff.text.strip() if aff.text else ""
        
        # Check for nested <orgName> elements
        org_name = aff.find('tei:orgName', namespaces=ns)
        if org_name is not None:
            org_name_text = org_name.text.strip() if org_name.text else ""
            # Combine the affiliation text with the organization name
            aff_text += f" {org_name_text}"
        # Add the processed occupation to the list
        affiliations_data.append(aff_text)
        # Join all occupations into a single string
        person_data['affiliations'] = "; ".join(affiliations_data)
    
    # Extract death date and description
    death = person.find('tei:death', namespaces=ns)
    person_data['death_date'] = death.get('when') if death is not None else None
    
    # Extract idnos
    #Wikidata
    wikidata=person.find('tei:idno[@subtype="WIKIDATA"]', namespaces=ns)
    person_data['Wikidata']=wikidata.text if wikidata is not None else None

    #WGW
    wgw=person.find('tei:idno[@subtype="WGW"]', namespaces=ns)
    person_data['WGW']=wgw.text if wgw is not None else None

    #GND
    gnd=person.find('tei:idno[@subtype="GND"]', namespaces=ns)
    person_data['GND']=gnd.text if gnd is not None else None

    #Wikipedia
    wikipedia=person.find('tei:idno[@subtype="Wikipedia"]', namespaces=ns)
    person_data['Wikipedia']=wikipedia.text if wikipedia is not None else None

    #ÖBL
    öbl=person.find('tei:idno[@subtype="ÖBL"]', namespaces=ns)
    person_data['ÖBL']=öbl.text if öbl is not None else None

    #PMB
    pmb=person.find('tei:idno[@subtype="PMB"]', namespaces=ns)
    person_data['PMB']=pmb.text if pmb is not None else None

    #VIAF
    viaf=person.find('tei:idno[@subtype="VIAF"]', namespaces=ns)
    person_data['VIAF']=viaf.text if viaf is not None else None
    
    # Append the person's data to the list
    data.append(person_data)

# Convert to pandas DataFrame
df_person = pd.DataFrame(data)

#Fill empty rows (needed for json later on)
df_person= df_person.fillna("")

#Duplicate ID and create website-name in new column
df_person['Website']=df_person.loc[:,'ID']+f".html"

# Save to a CSV file
df_person.to_csv("C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/csv/person_index.csv", index=False)
df_person.to_excel("C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/Excel/person_index.xlsx", index=False)

# Display the DataFrame
print(df_person)
# Out:
# Number of <person> elements found: 74
#                ID  forename                 surname surname maiden  \
# 0   LudwigLobmeyr    Ludwig                 Lobmeyr
# 1   JosephLobmeyr    Joseph                 Lobmeyr
# 2    FranzLobmeyr     Franz                 Lobmeyr
# 3    LouiseKralik    Louise  Kralik von Meyrswalden        Lobmeyr
# 4     HannsKralik     Hanns  Kralik von Meyrswalden
# ..            ...       ...                     ...            ...
# 69   ErnstDohnany     Ernst            von Dohnányi
# 70      Beethoven    Ludwig           van Beethoven
# 71         Mozart  Wolfgang                  Mozart
# 72          Haydn    Joseph                   Haydn
# 73        LeoXIII       Leo                    XIII
#
#                        occupations  \
# 0             k. k. Hofglashändler
# 1             k. k. Hofglashändler
# 2   k. k. Linienschiffs-Lieutenant
# 3
# 4
# ..                             ...
# 69
# 70
# 71
# 72
# 73
#
#                                          affiliations  death_date    Wikidata  \
# 0    Österreichisches Herrenhaus;  k. k.Akademie d...  1917-03-25   Q55847850
# 1
# 2
# 3                                                      1905-10-03  Q133874636
# 4
# ..                                                ...         ...         ...
# 69                                                                     Q78532
# 70                                                                       Q255
# 71                                                                       Q254
# 72                                                                      Q7349
# 73                                                                     Q43922
#
#    WGW        GND Wikipedia ÖBL PMB VIAF             Website
# 0                                         LudwigLobmeyr.html
# 1                                         JosephLobmeyr.html
# 2                                          FranzLobmeyr.html
# 3                                          LouiseKralik.html
# 4                                           HannsKralik.html
# ..  ..        ...       ...  ..  ..  ...                 ...
# 69      119110016                          ErnstDohnany.html
# 70      118508288                             Beethoven.html
# 71      118584596                                Mozart.html
# 72      118547356                                 Haydn.html
# 73                                              LeoXIII.html
#
# [74 rows x 15 columns]

# %% [markdown]
# ## **2.2. Index place**

# %%
# Extract <place> elements
places = root.xpath('//tei:listPlace/tei:place', namespaces=ns)
print(f"Number of <place> elements found: {len(places)}")

# Extract data
data_place = []
for place in places:
    place_data = {}
    # Extract xml:id
    place_data['ID'] = place.get('{http://www.w3.org/XML/1998/namespace}id')
    
    # Extract placeName
    placename = place.find('tei:placeName', namespaces=ns)
    place_data['name'] = placename.text if placename is not None else None

    #Extract type placeName
    placename_ref=placename.get('type') if placename is not None else None
    place_data['type'] = f"{placename_ref}" if placename is not None else None
    
    # Extract geo
    geo = place.find('tei:location/tei:geo', namespaces=ns)
    place_data['geo'] = geo.text if geo is not None else None
    
    # Extract idnos
    #Wikipedia
    wikipedia = place.find('tei:idno[@subtype="Wikipedia"]', namespaces=ns)
    place_data['Wikipedia']=wikipedia.text if wikipedia is not None else None

    #Wikidata
    wikidata=place.find('tei:idno[@subtype="WIKIDATA"]', namespaces=ns)
    place_data['WIKIDATA']=wikidata.text if wikidata is not None else None

    #Geonames
    geonames=place.find('tei:idno[@subtype="geonames"]', namespaces=ns)
    place_data['Geonames']=geonames.text if geonames is not None else None

    #WGW
    wgw=place.find('tei:idno[@subtype="WGW"]', namespaces=ns)
    place_data['WGW']=wgw.text if wgw is not None else None

    #GND
    gnd=place.find('tei:idno[@subtype="GND"]', namespaces=ns)
    place_data['GND']=gnd.text if gnd is not None else None
    
    # Append the data to the list
    data_place.append(place_data)

# Convert to pandas DataFrame
df_place = pd.DataFrame(data_place)

#Fill empty rows (needed for json later on)
df_place = df_place.fillna("")

#Duplicate ID and create website-name in new column
df_place['Website']=df_place.loc[:,'ID']+f".html"

# Save to a CSV file
df_place.to_csv("C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/csv/place_index.csv", index=False)
df_place.to_excel("C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/Excel/place_index.xlsx", index=False)

# Display the DataFrame
print(df_place)
# Out:
# Number of <place> elements found: 28
#                          ID  \
# 0                      Wien
# 1           Weimarerplatz_3
# 2         DöblingerFriedhof
# 3           WähringerKirche
# 4        Rosensteingasse_32
# 5   HernalserHauptstraße_81
# 6           EhrengrabKralik
# 7               Stephansdom
# 8          StMarxerFriedhof
# 9                    Weimar
# 10          Zentralfriedhof
# 11          GoldeggGasse_19
# 12       Favoritenstraße_27
# 13              Vorderbrühl
# 14        Elisabethstraße_1
# 15        Augustinerkircher
# 16        KärntnerStraße_21
# 17               Rennweg_91
# 18          ErdbergerKirche
# 19            KircheMödling
# 20            Eleonorenhain
# 21                 Annathal
# 22   Zentralfriedhof_Halle1
# 23        WeimarerStraße_89
# 24            Bendlgasse_24
# 25                   Berlin
# 26               Seccession
# 27                     Linz
#
#                                                  name      type  \
# 0                                                Wien      city
# 1                                     Weimarerplatz 3    street
# 2                                  Döblinger Friedhof  cemetery
# 3   Pfarrkirche heilige Gertraud und heiliger Laur...    church
# 4                                  Rosensteingasse 32    street
# 5                            Hernalser Hauptstraße 81    street
# 6                            Ehrengrab Richard Kralik  cemetery
# 7          Dom- und Metropolitankirche zu St. Stephan    church
# 8                                 St. Marxer Friedhof  cemetery
# 9                                              Weimar      city
# 10                                    Zentralfriedhof  cemetery
# 11                                   Goldegg-Gasse 19    street
# 12                                 Favoritenstraße 27    street
# 13                                        Vorderbrühl   village
# 14                                  Elisabethstraße 1    street
# 15                                   Augustinerkirche    church
# 16                                 Kärntner Straße 21    street
# 17                                         Rennweg 91    street
# 18                              Peter-und-Paul-Kirche    church
# 19                           Stadtpfarrkirche Mödling    church
# 20                                      Eleonorenhain   village
# 21                                           Annathal   village
# 22                      Zentralfriedhof Halle 1 Tor 2  cemetery
# 23                                 Weimarer Straße 89    street
# 24                                      Bendlgasse 24    street
# 25                                             Berlin      city
# 26                                         Seccession    museum
# 27                                               Linz      city
#
#                                        geo  \
# 0                       48.20849, 16.37208
# 1   48.233902622021546, 16.344070193512067
# 2   48.238719731402156, 16.328673269061063
# 3     48.22621692059329, 16.34450228069556
# 4    48.21808403776477, 16.326086765349057
# 5    48.21845628508243, 16.328900153713658
# 6
# 7    48.20854411963058, 16.373480666951327
# 8      48.18402446536315, 16.4032053383651
# 9                        50.9803, 11.32903
# 10    48.1514660511102, 16.438521926727077
# 11    48.18976066981652, 16.37695638069264
# 12  48.189747763641684, 16.372364634655163
# 13                      48.08284, 16.25874
# 14  48.201765590654134, 16.368675138366534
# 15   48.20610677964904, 16.367669853712695
# 16  48.206327276134346, 16.371738011385606
# 17   48.19044582541425, 16.397931765346893
# 18  48.200857294744246, 16.398227150471623
# 19  48.085662256259745, 16.280088723318332
# 20    48.9343471954487, 13.794896645500788
# 21   48.87337398216413, 13.614796312599777
# 22  48.153249181929844, 16.442484911381403
# 23    48.2367713611113, 16.344899553715038
# 24   48.17974233449344, 16.335147009528303
# 25                      52.52437, 13.41053
# 26                      48.20041, 16.36542
# 27                      48.30639, 14.28611
#
#                                             Wikipedia    WIKIDATA  \
# 0                                                           Q1741
# 1   https://de.wikipedia.org/wiki/Richard-Kralik-P...
# 2   https://de.wikipedia.org/wiki/D%C3%B6blinger_F...    Q1270909
# 3   https://de.wikipedia.org/wiki/W%C3%A4hringer_P...
# 4
# 5
# 6
# 7
# 8
# 9                                                           Q3955
# 10  https://de.wikipedia.org/wiki/Wiener_Zentralfr...     Q240744
# 11
# 12
# 13                                                     Q114048876
# 14
# 15
# 16
# 17
# 18
# 19
# 20
# 21
# 22  https://de.wikipedia.org/wiki/Wiener_Zentralfr...     Q240744
# 23
# 24
# 25                                                          Q1741
# 26                                                        Q265129
# 27                                                         Q41329
#
#                                              Geonames    WGW         GND  \
# 0        https://www.geonames.org/2761369/vienna.html
# 1                                                      26530
# 2                                                       6843  1233214810
# 3                                                       3616
# 4
# 5
# 6
# 7
# 8                                                      18057   4843295-7
# 9
# 10                                                      9327   4120093-7
# 11
# 12
# 13  https://www.geonames.org/2762284/vorderbruehl....
# 14
# 15                                                     28422
# 16
# 17
# 18                                                     14138
# 19
# 20
# 21
# 22                                                      9327   4120093-7
# 23
# 24
# 25       https://www.geonames.org/2950159/berlin.html
# 26    https://www.geonames.org/6354994/secession.html
# 27         https://www.geonames.org/2772400/linz.html
#
#                          Website
# 0                      Wien.html
# 1           Weimarerplatz_3.html
# 2         DöblingerFriedhof.html
# 3           WähringerKirche.html
# 4        Rosensteingasse_32.html
# 5   HernalserHauptstraße_81.html
# 6           EhrengrabKralik.html
# 7               Stephansdom.html
# 8          StMarxerFriedhof.html
# 9                    Weimar.html
# 10          Zentralfriedhof.html
# 11          GoldeggGasse_19.html
# 12       Favoritenstraße_27.html
# 13              Vorderbrühl.html
# 14        Elisabethstraße_1.html
# 15        Augustinerkircher.html
# 16        KärntnerStraße_21.html
# 17               Rennweg_91.html
# 18          ErdbergerKirche.html
# 19            KircheMödling.html
# 20            Eleonorenhain.html
# 21                 Annathal.html
# 22   Zentralfriedhof_Halle1.html
# 23        WeimarerStraße_89.html
# 24            Bendlgasse_24.html
# 25                   Berlin.html
# 26               Seccession.html
# 27                     Linz.html

# %% [markdown]
# ## **2.3. Index organisation**

# %%
# Extract <org> elements
orgs = root.xpath('//tei:listOrg/tei:org', namespaces=ns)
print(f"Number of <org> elements found: {len(orgs)}")

# Extract data
data_org = []
for org in orgs:
    org_data = {}
    # Extract xml:id
    org_data['ID'] = org.get('{http://www.w3.org/XML/1998/namespace}id')
    
    # Extract orgName
    orgname = org.find('tei:orgName', namespaces=ns)
    org_data['name'] = orgname.text if orgname is not None else f""

    #Extract type orgName
    orgname_ref=orgname.get('type') if orgname is not None else None
    org_data['type'] = f"{orgname_ref}" if orgname is not None else None
    
    #Extract idnos
    #Wikipedia
    wikipedia = org.find('tei:idno[@subtype="Wikipedia"]', namespaces=ns)
    org_data['Wikipedia']=wikipedia.text if wikipedia is not None else None

    #Wikidata
    wikidata=org.find('tei:idno[@subtype="WIKIDATA"]', namespaces=ns)
    org_data['WIKIDATA']=wikidata.text if wikidata is not None else None

    #WGW
    wgw=org.find('tei:idno[@subtype="WGW"]', namespaces=ns)
    org_data['WGW']=wgw.text if wgw is not None else None

    #GND
    gnd=org.find('tei:idno[@subtype="GND"]', namespaces=ns)
    org_data['GND']=gnd.text if gnd is not None else None
    
    # Append the data to the list
    data_org.append(org_data)

# Convert to pandas DataFrame
df_org = pd.DataFrame(data_org)

#Fill empty rows (needed for json later on)
df_org = df_org.fillna("")

#Duplicate ID and create website-name in new column
df_org['Website']=df_org.loc[:,'ID']+f".html"

# Save to a CSV file
df_org.to_csv("C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/csv/org_index.csv", index=False)
df_org.to_excel("C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/Excel/org_index.xlsx", index=False)

# Display the DataFrame
print(df_org)
# Out:
# Number of <org> elements found: 22
#                              ID  \
# 0                     JLLobmeyr
# 1                        Gerold
# 2                    Herrenhaus
# 3                        AkBild
# 4        GenossenschaftKünstler
# 5              Schillerstiftung
# 6                 TheyerHartmut
# 7   StädtischeLeichenbestattung
# 8                    DruckBileg
# 9    GeneralinspektionEisenbahn
# 10                Statthalterei
# 11           Enterprisefunebres
# 12                   Bärenhöhle
# 13                     Nordbahn
# 14         EisenbahnMinisterium
# 15              BestattungPayer
# 16                     Lischkar
# 17                    Vaterland
# 18                  FreiePresse
# 19                   Extrablatt
# 20                   MeyrsNeffe
# 21         WienerKonservatorium
#
#                                                  name           type  \
# 0                                    J. & L. Lobmeyr     manufactory
# 1                                         Gerold & Co        printer
# 2                                          Herrenhaus  representativ
# 3                       Akademie der bildenden Künste       cultural
# 4         Genossenschaft der bildenden Künstler Wiens       cultural
# 5                           Deutsche Schillerstiftung       cultural
# 6                                  THEYER & HARDTMUTH          paper
# 7                        Städtische Leichenbestattung        funeral
# 8                                         Josef Bileg        printer
# 9   Generalinspektion der österreichischen Eisenba...      transport
# 10                      Küstenländische Statthalterei      political
# 11                     Entreprise des pompes funèbres        funeral
# 12                                         Bärenhöhle      political
# 13                         Kaiser-Ferdinands-Nordbahn      transport
# 14                            Eisenbahnen-Ministerium      political
# 15                              Payer, Schmutzer & Co        funeral
# 16                                      Lischkar & Co        printer
# 17                                          Vaterland          press
# 18                                  Neue Freie Presse          press
# 19                     Illustrirtes Wiener Extrablatt          press
# 20                                       Meyr's Neffe    manufactory
# 21                              Wiener Konservatorium       cultural
#
#                                             Wikipedia    WIKIDATA    WGW  \
# 0                                                         Q876883  17959
# 1                                                                  19514
# 2                                                                  12008
# 3                                                         Q414219  17555
# 4                                                         Q284902  25052
# 5
# 6                                                                  46454
# 7
# 8
# 9
# 10
# 11
# 12                                                                 42579
# 13  https://de.wikipedia.org/wiki/Kaiser_Ferdinand...     Q352763  21891
# 14  https://de.wikipedia.org/wiki/K.k._Eisenbahnmi...
# 15
# 16
# 17                                                     Q125847075
# 18                                                       Q2919142
# 19                                                       Q1658926
# 20                                                       Q1926388
# 21                                                      Q28864370
#
#           GND                           Website
# 0                                JLLobmeyr.html
# 1                                   Gerold.html
# 2                               Herrenhaus.html
# 3   2003761-2                       AkBild.html
# 4   2100204-6       GenossenschaftKünstler.html
# 5   5187203-1             Schillerstiftung.html
# 6                            TheyerHartmut.html
# 7              StädtischeLeichenbestattung.html
# 8                               DruckBileg.html
# 9               GeneralinspektionEisenbahn.html
# 10                           Statthalterei.html
# 11                      Enterprisefunebres.html
# 12                              Bärenhöhle.html
# 13  4276204-2                     Nordbahn.html
# 14                    EisenbahnMinisterium.html
# 15                         BestattungPayer.html
# 16                                Lischkar.html
# 17                               Vaterland.html
# 18                             FreiePresse.html
# 19                              Extrablatt.html
# 20                              MeyrsNeffe.html
# 21                    WienerKonservatorium.html

# %% [markdown]
# ## **2.4. Index relationships**

# %%
#Created with the help of u:ai
# Extract <relation> elements
relations = root.xpath('//tei:listRelation/tei:relation', namespaces=ns)

# Extract data
relation_data = []
for relation in relations:
    relation_entry = {}
    # Extract relation name
    relation_entry['name'] = relation.get('name')
    
    # Extract active attribute
    relation_entry['active'] = relation.get('active')
    
    # Extract passive attribute
    relation_entry['passive'] = relation.get('passive')
    
    # Extract mutual attribute
    relation_entry['mutual'] = relation.get('mutual')
    
    # Append the relation entry to the list
    relation_data.append(relation_entry)

# Convert to pandas DataFrame
df_relations = pd.DataFrame(relation_data)

# Function to process each cell
def process_names(cell):
    if pd.isna(cell):  # Check if the cell is None or NaN
        return cell  # Return as is (or return an empty string if preferred)
    
    # Step 1: Insert a comma between each #VornameNachname
    cell = cell.replace(' #', ';#')  # Add a comma before each `#` (except the first one)
    
    # Step 2: Remove the '#' symbol
    cell = cell.replace('#', '')
    
    # Step 3: Split each name at capital letters and join with spaces
    processed_names = [' '.join(re.findall(r'[A-Z][a-z]*', name)) for name in cell.split(',')]
    
    # Step 4: Join the processed names back into a single string with commas
    return ', '.join(processed_names)

df_relations['active'] = df_relations['active'].apply(process_names)
df_relations['passive'] = df_relations['passive'].apply(process_names)
df_relations['mutual'] = df_relations['mutual'].apply(process_names)

# Display the updated DataFrame
print(df_relations)

# Save to a CSV file (optional)
df_relations.to_csv("C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/csv/relation_index.csv", index=False)


# Display the DataFrame
print(df_relations)
# Out:
#            name           active  \
# 0        parent      August Rath
# 1        parent  Aloisia Lobmeyr
# 2        parent    Louise Kralik
# 3        parent      Maia Kralik
# 4        parent   Richard Kralik
# 5        parent  Aloisia Pichler
# 6        parent   Eduard Pichler
# 7   grandparent    Louise Kralik
# 8   grandparent      Maia Kralik
# 9   grandparent   Richard Kralik
# 10      sibling             None
# 11      sibling             None
# 12      sibling             None
# 13      sibling             None
# 14      sibling             None
# 15      sibling             None
# 16        uncle   Ludwig Lobmeyr
# 17        uncle    Ludwig Kralik
# 18       spouse             None
# 19       spouse             None
# 20       spouse             None
# 21       spouse             None
# 22      partner             None
#
#                                               passive  \
# 0   Marie Sch Kreuzenau August Rathjun Paul Rath S...
# 1   Joseph Lobmeyr Ludwig Lobmeyr Franz Lobmeyr Lo...
# 2      Richard Kralik Mathilde Kralik Aloisia Pichler
# 3      Dietrich Kralik Heinrich Kralik Rodrich Kralik
# 4      Dietrich Kralik Heinrich Kralik Rodrich Kralik
# 5                          Ilse Pichler Edith Pichler
# 6                          Ilse Pichler Edith Pichler
# 7   Dietrich Kralik Heinrich Kralik Rodrich Kralik...
# 8      Winifred Kralik Leopold Kralik Elfriede Kralik
# 9      Winifred Kralik Leopold Kralik Elfriede Kralik
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16  Rudolf Lobmeyr Adolf Lobmeyr Oskar Lobmeyr Lud...
# 17  Dietrich Kralik Heinrich Kralik Rodrich Kralik...
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                                mutual
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10         Louise Kralik Ludwig Lobmeyr Mathilde Rath
# 11  Rudolf Lobmeyr Adolf Lobmeyr Oskar Lobmeyr Lud...
# 12  Marie Sch Kreuzenau August Rathjun Paul Rath S...
# 13     Richard Kralik Mathilde Kralik Aloisia Pichler
# 14  Joseph Lobmeyr Ludwig Lobmeyr Franz Lobmeyr Lo...
# 15     Heinrich Kralik Rodrich Kralik Dietrich Kralik
# 16                                               None
# 17                                               None
# 18                       Louise Kralik Wilhelm Kralik
# 19                    Hildegard Lobmeyr Franz Lobmeyr
# 20                         Maia Kralik Richard Kralik
# 21                     Aloisia Pichler Eduard Pichler
# 22                    Alice Scarlates Mathilde Kralik
#            name           active  \
# 0        parent      August Rath
# 1        parent  Aloisia Lobmeyr
# 2        parent    Louise Kralik
# 3        parent      Maia Kralik
# 4        parent   Richard Kralik
# 5        parent  Aloisia Pichler
# 6        parent   Eduard Pichler
# 7   grandparent    Louise Kralik
# 8   grandparent      Maia Kralik
# 9   grandparent   Richard Kralik
# 10      sibling             None
# 11      sibling             None
# 12      sibling             None
# 13      sibling             None
# 14      sibling             None
# 15      sibling             None
# 16        uncle   Ludwig Lobmeyr
# 17        uncle    Ludwig Kralik
# 18       spouse             None
# 19       spouse             None
# 20       spouse             None
# 21       spouse             None
# 22      partner             None
#
#                                               passive  \
# 0   Marie Sch Kreuzenau August Rathjun Paul Rath S...
# 1   Joseph Lobmeyr Ludwig Lobmeyr Franz Lobmeyr Lo...
# 2      Richard Kralik Mathilde Kralik Aloisia Pichler
# 3      Dietrich Kralik Heinrich Kralik Rodrich Kralik
# 4      Dietrich Kralik Heinrich Kralik Rodrich Kralik
# 5                          Ilse Pichler Edith Pichler
# 6                          Ilse Pichler Edith Pichler
# 7   Dietrich Kralik Heinrich Kralik Rodrich Kralik...
# 8      Winifred Kralik Leopold Kralik Elfriede Kralik
# 9      Winifred Kralik Leopold Kralik Elfriede Kralik
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16  Rudolf Lobmeyr Adolf Lobmeyr Oskar Lobmeyr Lud...
# 17  Dietrich Kralik Heinrich Kralik Rodrich Kralik...
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                                mutual
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10         Louise Kralik Ludwig Lobmeyr Mathilde Rath
# 11  Rudolf Lobmeyr Adolf Lobmeyr Oskar Lobmeyr Lud...
# 12  Marie Sch Kreuzenau August Rathjun Paul Rath S...
# 13     Richard Kralik Mathilde Kralik Aloisia Pichler
# 14  Joseph Lobmeyr Ludwig Lobmeyr Franz Lobmeyr Lo...
# 15     Heinrich Kralik Rodrich Kralik Dietrich Kralik
# 16                                               None
# 17                                               None
# 18                       Louise Kralik Wilhelm Kralik
# 19                    Hildegard Lobmeyr Franz Lobmeyr
# 20                         Maia Kralik Richard Kralik
# 21                     Aloisia Pichler Eduard Pichler
# 22                    Alice Scarlates Mathilde Kralik

# %% [markdown]
# # **3. Converting csv to json**

# %% [markdown]
# ## **3.1. json-person**

# %%
#CODE FOR JSON WITH EMPTY LINES
# Function to clean and preprocess data
#Created with u:ai
def preprocess_value(value):
    """
    Cleans and preprocesses a value:
    - Strips leading/trailing whitespace
    - Replaces empty strings or invalid data with None
    """
    if pd.isna(value) or str(value).strip() == '':
        return f""
    return str(value).strip()

# Apply preprocessing to all cells in the DataFrame
df_person = df_person.applymap(preprocess_value)

# Function to remove keys with None values
def remove_null_values(record):
    """
    Removes keys with None values from a dictionary.
    """
    return {key: value for key, value in record.items() if value is not None}

# Convert the DataFrame to a list of dictionaries and remove null values
person_records = [remove_null_values(record) for record in df_person.to_dict(orient='records')]

# Wrap the list of person records in a dictionary with a "data" key
person_json_data = {
    "data": person_records
}

# Write the JSON to a file
output_file_path = 'C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/json/person_index.json'
with open(output_file_path, 'w', encoding='utf-8') as json_file:
    json.dump(person_json_data, json_file, indent=4, ensure_ascii=False)

# Display the JSON structure (optional, for debugging)
print(json.dumps(person_json_data, indent=4, ensure_ascii=False))
# Out:
# {
#     "data": [
#         {
#             "ID": "LudwigLobmeyr",
#             "forename": "Ludwig",
#             "surname": "Lobmeyr",
#             "surname maiden": "",
#             "occupations": "k. k. Hofglashändler",
#             "affiliations": "Österreichisches Herrenhaus;  k. k.Akademie der bildenden Künste;  Genossenschaft der bildenden Künstler Wiens;  Deutsche Schillerstiftung",
#             "death_date": "1917-03-25",
#             "Wikidata": "Q55847850",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "LudwigLobmeyr.html"
#         },
#         {
#             "ID": "JosephLobmeyr",
#             "forename": "Joseph",
#             "surname": "Lobmeyr",
#             "surname maiden": "",
#             "occupations": "k. k. Hofglashändler",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "JosephLobmeyr.html"
#         },
#         {
#             "ID": "FranzLobmeyr",
#             "forename": "Franz",
#             "surname": "Lobmeyr",
#             "surname maiden": "",
#             "occupations": "k. k. Linienschiffs-Lieutenant",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "FranzLobmeyr.html"
#         },
#         {
#             "ID": "LouiseKralik",
#             "forename": "Louise",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "Lobmeyr",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "1905-10-03",
#             "Wikidata": "Q133874636",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "LouiseKralik.html"
#         },
#         {
#             "ID": "HannsKralik",
#             "forename": "Hanns",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "HannsKralik.html"
#         },
#         {
#             "ID": "HeinrichKralikSen",
#             "forename": "Heinrich",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "Glasfabrikant",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "https://de.wikipedia.org/wiki/Heinrich_Kralik_von_Meyrswalden_(Industrieller)",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "HeinrichKralikSen.html"
#         },
#         {
#             "ID": "MathildeRath",
#             "forename": "Mathilde",
#             "surname": "Rath",
#             "surname maiden": "Lobmeyr",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "MathildeRath.html"
#         },
#         {
#             "ID": "WilhelmKralik",
#             "forename": "Wilhelm",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "Glasfabriken-Besitzer",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "Q2573745",
#             "WGW": "",
#             "GND": "136539696",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "WilhelmKralik.html"
#         },
#         {
#             "ID": "LudwigKralik",
#             "forename": "Ludwig",
#             "surname": "Ritter Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "Oberingenieur der Kaiser-Ferdinand-Nordbahn",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "LudwigKralik.html"
#         },
#         {
#             "ID": "HildegardLobmeyr",
#             "forename": "Hildegard",
#             "surname": "Lobmeyr",
#             "surname maiden": "von Stahlberg",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "HildegardLobmeyr.html"
#         },
#         {
#             "ID": "AloisiaLobmeyr",
#             "forename": "Aloisia",
#             "surname": "Lobmeyr",
#             "surname maiden": "Dobratsky",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "1864-01-26",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "AloisiaLobmeyr.html"
#         },
#         {
#             "ID": "CarlGerold",
#             "forename": "Carl",
#             "surname": "Gerold",
#             "surname maiden": "",
#             "occupations": "Buchdrucker",
#             "affiliations": "Gerold & Co",
#             "death_date": "",
#             "Wikidata": "Q61995654",
#             "WGW": "19487",
#             "GND": "133262871",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "CarlGerold.html"
#         },
#         {
#             "ID": "RudolfLobmeyr",
#             "forename": "Rudolf",
#             "surname": "Lobmeyr",
#             "surname maiden": "",
#             "occupations": "k. k. Bezirkshauptmann",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "RudolfLobmeyr.html"
#         },
#         {
#             "ID": "AdolfLobmeyr",
#             "forename": "Adolf",
#             "surname": "Lobmeyr",
#             "surname maiden": "",
#             "occupations": "Oberinspektionsrat der Generalinspektion der österreichischen Eisenbahnen",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "AdolfLobmeyr.html"
#         },
#         {
#             "ID": "OskarLobmeyr",
#             "forename": "Oskar",
#             "surname": "von Lobmeyr",
#             "surname maiden": "",
#             "occupations": "Vize-Präsident der küstenländischen Statthalterei",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "1157623174",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "OskarLobmeyr.html"
#         },
#         {
#             "ID": "LudwigLobmeyrJun",
#             "forename": "Ludwig",
#             "surname": "Lobmeyr",
#             "surname maiden": "",
#             "occupations": "k. k. Rittmeister",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "LudwigLobmeyrJun.html"
#         },
#         {
#             "ID": "JennyLobmeyr",
#             "forename": "Jenny",
#             "surname": "Lobmeyr",
#             "surname maiden": "Ruße",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "JennyLobmeyr.html"
#         },
#         {
#             "ID": "MarieLobmeyr",
#             "forename": "Marie",
#             "surname": "Lobmeyr",
#             "surname maiden": "Steinhuber",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "MarieLobmeyr.html"
#         },
#         {
#             "ID": "EllyLobmeyr",
#             "forename": "Elly",
#             "surname": "von Lobmeyr",
#             "surname maiden": "Arbeßer von Rastburg",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "EllyLobmeyr.html"
#         },
#         {
#             "ID": "GretlLobmeyr",
#             "forename": "Gretl",
#             "surname": "Lobmeyr",
#             "surname maiden": "Handofsky",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "GretlLobmeyr.html"
#         },
#         {
#             "ID": "HermannSpaun",
#             "forename": "Hermann",
#             "surname": "von Spaun",
#             "surname maiden": "",
#             "occupations": "Geheimer Rat; k. k. Admiral",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "103544075X",
#             "Wikipedia": "",
#             "ÖBL": "https://www.biographien.ac.at/oebl/oebl_S/Spaun_Hermann_1833_1919.xml",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "HermannSpaun.html"
#         },
#         {
#             "ID": "AugustRath",
#             "forename": "August",
#             "surname": "Rath",
#             "surname maiden": "",
#             "occupations": "kaiserlicher Rat",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "AugustRath.html"
#         },
#         {
#             "ID": "MarieSchönvonKreuzenau",
#             "forename": "Marie",
#             "surname": "Schön von Kreuzenau",
#             "surname maiden": "Rath",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "MarieSchönvonKreuzenau.html"
#         },
#         {
#             "ID": "AugustRathjun",
#             "forename": "August",
#             "surname": "Rath jun.",
#             "surname maiden": "",
#             "occupations": "Großindustrieller",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "AugustRathjun.html"
#         },
#         {
#             "ID": "PaulRath",
#             "forename": "Paul",
#             "surname": "Rath",
#             "surname maiden": "",
#             "occupations": "k.k. Oberst",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "PaulRath.html"
#         },
#         {
#             "ID": "StefanRath",
#             "forename": "Stefan",
#             "surname": "Rath",
#             "surname maiden": "",
#             "occupations": "k. k. Oberleutnant i. V. d. E.; Gesellschafter der Firma J. & L. Lobmeyr",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "StefanRath.html"
#         },
#         {
#             "ID": "AdeleRath",
#             "forename": "Adele",
#             "surname": "Rath",
#             "surname maiden": "Wagenmann",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "AdeleRath.html"
#         },
#         {
#             "ID": "KarlPichler",
#             "forename": "Karl",
#             "surname": "Pichler von Deeben",
#             "surname maiden": "",
#             "occupations": "k. k. Ministerialrat",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "KarlPichler.html"
#         },
#         {
#             "ID": "MathildeKralik",
#             "forename": "Mathilde",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "Komponistin",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "Q89972",
#             "WGW": "37789",
#             "GND": "130214566",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "19659",
#             "VIAF": "",
#             "Website": "MathildeKralik.html"
#         },
#         {
#             "ID": "AloisiaPichler",
#             "forename": "Louisa",
#             "surname": "Pichler von Deeben",
#             "surname maiden": "Kralik von Meyrswalden",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "AloisiaPichler.html"
#         },
#         {
#             "ID": "MinnaKralik",
#             "forename": "Minna",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "MinnaKralik.html"
#         },
#         {
#             "ID": "RichardKralik",
#             "forename": "Richard",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "1934-02-04",
#             "Wikidata": "Q1317482",
#             "WGW": "16425",
#             "GND": "118777920",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "3731",
#             "VIAF": "",
#             "Website": "RichardKralik.html"
#         },
#         {
#             "ID": "MaiaKralik",
#             "forename": "Maia",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "von Flattich",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "116385863",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "MaiaKralik.html"
#         },
#         {
#             "ID": "EduardPichler",
#             "forename": "Eduard",
#             "surname": "Pichler von Deeben",
#             "surname maiden": "",
#             "occupations": "k. k. Ministerialrat; Sektionsrat im Eisenbahn-Ministerium",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "EduardPichler.html"
#         },
#         {
#             "ID": "JosefBileg",
#             "forename": "Josef",
#             "surname": "Bileg",
#             "surname maiden": "",
#             "occupations": "Drucker",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "JosefBileg.html"
#         },
#         {
#             "ID": "AgnesKralik",
#             "forename": "Agnes",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "AgnesKralik.html"
#         },
#         {
#             "ID": "EduardSchmid",
#             "forename": "Eduard",
#             "surname": "Schmid",
#             "surname maiden": "",
#             "occupations": "Glasfabrikant",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "1030547009",
#             "Wikipedia": "",
#             "ÖBL": "https://www.biographien.ac.at/oebl/oebl_S/Schmid_Josef-Eduard_1836_1910.xml",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "EduardSchmid.html"
#         },
#         {
#             "ID": "CarlKralik",
#             "forename": "Carl",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "CarlKralik.html"
#         },
#         {
#             "ID": "JosefTaschek",
#             "forename": "Josef",
#             "surname": "Taschek",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "Q8311993",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "https://de.wikipedia.org/wiki/Josef_Taschek",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "JosefTaschek.html"
#         },
#         {
#             "ID": "DietrichKralik",
#             "forename": "Dietrich",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "Universitätsprofessor",
#             "affiliations": "Bärenhöhle",
#             "death_date": "",
#             "Wikidata": "Q1223897",
#             "WGW": "16414",
#             "GND": "118777912",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "DietrichKralik.html"
#         },
#         {
#             "ID": "HeinrichKralik",
#             "forename": "Heinrich",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "Q1235353",
#             "WGW": "16424",
#             "GND": "121829324",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "HeinrichKralik.html"
#         },
#         {
#             "ID": "RodrichKralik",
#             "forename": "Rodrich",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "Landesgerichtsrat",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "11638610X",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "RodrichKralik.html"
#         },
#         {
#             "ID": "EdithPichler",
#             "forename": "Edith",
#             "surname": "Pichler von Deeben",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "EdithPichler.html"
#         },
#         {
#             "ID": "IlsePichler",
#             "forename": "Ilse",
#             "surname": "Pichler von Deeben",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "IlsePichler.html"
#         },
#         {
#             "ID": "HannahKralik",
#             "forename": "Hannah",
#             "surname": "Kralik von Meyerswalden",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "HannahKralik.html"
#         },
#         {
#             "ID": "GretlKralik",
#             "forename": "Gretl",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "GretlKralik.html"
#         },
#         {
#             "ID": "LuiseKralik",
#             "forename": "Luise",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "LuiseKralik.html"
#         },
#         {
#             "ID": "WinifredKralik",
#             "forename": "Winifred",
#             "surname": "Kralik",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "Q59653649",
#             "WGW": "37795",
#             "GND": "118643274",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "WinifredKralik.html"
#         },
#         {
#             "ID": "LeopoldKralik",
#             "forename": "Leopold",
#             "surname": "Kralik",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "LeopoldKralik.html"
#         },
#         {
#             "ID": "ElfriedeKralik",
#             "forename": "Elfriede",
#             "surname": "Kralik",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "ElfriedeKralik.html"
#         },
#         {
#             "ID": "TheodorInnitzer",
#             "forename": "Theodor",
#             "surname": "Innitzer",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "Q78988",
#             "WGW": "13273",
#             "GND": "118555634",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "57443",
#             "VIAF": "",
#             "Website": "TheodorInnitzer.html"
#         },
#         {
#             "ID": "RudolfWieser",
#             "forename": "Rudolf",
#             "surname": "Wieser",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "RudolfWieser.html"
#         },
#         {
#             "ID": "EdmundSteinbock",
#             "forename": "Edmund",
#             "surname": "Steinbock",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "EdmundSteinbock.html"
#         },
#         {
#             "ID": "AliceScarlates",
#             "forename": "Alice",
#             "surname": "Scarlates",
#             "surname maiden": "",
#             "occupations": "Philologin; Dolmetscherin",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "Q52084077",
#             "WGW": "",
#             "GND": "1228633460",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "AliceScarlates.html"
#         },
#         {
#             "ID": "EduardHauptmann",
#             "forename": "Eduard",
#             "surname": "Hauptmann",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "EduardHauptmann.html"
#         },
#         {
#             "ID": "CarlHertlein",
#             "forename": "Carl",
#             "surname": "Hertlein",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "CarlHertlein.html"
#         },
#         {
#             "ID": "JuliusEpstein",
#             "forename": "Julius",
#             "surname": "Epstein",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "Q79036",
#             "WGW": "",
#             "GND": "116652357",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "JuliusEpstein.html"
#         },
#         {
#             "ID": "IreneZoepf",
#             "forename": "Irene",
#             "surname": "Zoepf",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "66893083",
#             "Website": "IreneZoepf.html"
#         },
#         {
#             "ID": "Herder",
#             "forename": "Johann",
#             "surname": "Herder",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "Q155547",
#             "WGW": "",
#             "GND": "118549553",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "Herder.html"
#         },
#         {
#             "ID": "Catull",
#             "forename": "Catull",
#             "surname": "",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "Q163079",
#             "WGW": "",
#             "GND": "118519719",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "Catull.html"
#         },
#         {
#             "ID": "JohannRathausky",
#             "forename": "Johann",
#             "surname": "Rathausky",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "1027435025",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "JohannRathausky.html"
#         },
#         {
#             "ID": "Sokrates",
#             "forename": "Sokrates",
#             "surname": "",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "Q913",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "Sokrates.html"
#         },
#         {
#             "ID": "Ilse",
#             "forename": "Ilse",
#             "surname": "",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "Ilse.html"
#         },
#         {
#             "ID": "FranziskaTschampa",
#             "forename": "Franziska",
#             "surname": "Tschampa",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "1081510544",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "FranziskaTschampa.html"
#         },
#         {
#             "ID": "LulaGmeiner",
#             "forename": "Lula",
#             "surname": "Gmeiner",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "Q1676668",
#             "WGW": "",
#             "GND": "117212490",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "LulaGmeiner.html"
#         },
#         {
#             "ID": "FranzNaval",
#             "forename": "Franz",
#             "surname": "Naval",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "Q87156",
#             "WGW": "",
#             "GND": "116266945",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "FranzNaval.html"
#         },
#         {
#             "ID": "MarcellaPregi",
#             "forename": "Marcella",
#             "surname": "Pregi",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "Q94761060",
#             "WGW": "",
#             "GND": "116281588",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "MarcellaPregi.html"
#         },
#         {
#             "ID": "Angiline",
#             "forename": "Angiline",
#             "surname": "",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "Angiline.html"
#         },
#         {
#             "ID": "RudolphFitzner",
#             "forename": "Rudolph",
#             "surname": "Fitzner",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "Q7377184",
#             "WGW": "",
#             "GND": "116586540",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "RudolphFitzner.html"
#         },
#         {
#             "ID": "ErnstDohnany",
#             "forename": "Ernst",
#             "surname": "von Dohnányi",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "Q78532",
#             "WGW": "",
#             "GND": "119110016",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "ErnstDohnany.html"
#         },
#         {
#             "ID": "Beethoven",
#             "forename": "Ludwig",
#             "surname": "van Beethoven",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "Q255",
#             "WGW": "",
#             "GND": "118508288",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "Beethoven.html"
#         },
#         {
#             "ID": "Mozart",
#             "forename": "Wolfgang",
#             "surname": "Mozart",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "Q254",
#             "WGW": "",
#             "GND": "118584596",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "Mozart.html"
#         },
#         {
#             "ID": "Haydn",
#             "forename": "Joseph",
#             "surname": "Haydn",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "Q7349",
#             "WGW": "",
#             "GND": "118547356",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "Haydn.html"
#         },
#         {
#             "ID": "LeoXIII",
#             "forename": "Leo",
#             "surname": "XIII",
#             "surname maiden": "",
#             "occupations": "",
#             "affiliations": "",
#             "death_date": "",
#             "Wikidata": "Q43922",
#             "WGW": "",
#             "GND": "",
#             "Wikipedia": "",
#             "ÖBL": "",
#             "PMB": "",
#             "VIAF": "",
#             "Website": "LeoXIII.html"
#         }
#     ]
# }
# C:\Users\annab\AppData\Local\Temp\ipykernel_11136\340704034.py:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_person = df_person.applymap(preprocess_value)

# %%
#CODE FOR JSON WITH NO EMPTY LINES
# Function to clean and preprocess data
#Created with u:ai
def preprocess_value(value):
    """
    Cleans and preprocesses a value:
    - Strips leading/trailing whitespace
    - Replaces empty strings or invalid data with None
    """
    if pd.isna(value) or str(value).strip() == '':
        return None
    return str(value).strip()

# Apply preprocessing to all cells in the DataFrame
df_person = df_person.applymap(preprocess_value)

# Function to parse complex fields (e.g., affiliations)
def parse_affiliations(affiliations):
    """
    Parses the 'affiliations' field into a structured list of dictionaries.
    """
    if not affiliations:
        return None
    # Split affiliations by tab or newline
    entries = re.split(r'\t|\n', affiliations)
    parsed_entries = []
    for entry in entries:
        # Extract key-value pairs from the entry
        match = re.match(r'type:\s*(.*?),\s*subtype:\s*(.*?),\s*orgName:\s*(.*?),\s*ref:\s*(.*)', entry)
        if match:
            parsed_entries.append({
                "type": match.group(1).strip(),
                "subtype": match.group(2).strip(),
                "orgName": match.group(3).strip(),
                "ref": match.group(4).strip()
            })
    return parsed_entries if parsed_entries else None

# Apply the parsing function to the 'affiliations' column
if 'affiliations' in df_person.columns:
    df_person['affiliations'] = df_person['affiliations'].apply(parse_affiliations)

# Function to remove keys with None values
def remove_null_values(record):
    """
    Removes keys with None values from a dictionary.
    """
    return {key: value for key, value in record.items() if value is not None}

# Convert the DataFrame to a list of dictionaries and remove null values
person_records = [remove_null_values(record) for record in df_person.to_dict(orient='records')]

# Wrap the list of person records in a dictionary with a "data" key
person_json_data = {
    "data": person_records
}

# Write the JSON to a file
output_file_path = 'C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/json/person_index_clean.json'
with open(output_file_path, 'w', encoding='utf-8') as json_file:
    json.dump(person_json_data, json_file, indent=4, ensure_ascii=False)

# Display the JSON structure (optional, for debugging)
print(json.dumps(person_json_data, indent=4, ensure_ascii=False))
# Out:
# {
#     "data": [
#         {
#             "ID": "LudwigLobmeyr",
#             "forename": "Ludwig",
#             "surname": "Lobmeyr",
#             "occupations": "k. k. Hofglashändler",
#             "death_date": "1917-03-25",
#             "idnos": "ID (WIKIDATA): Q55847850"
#         },
#         {
#             "ID": "JosephLobmeyr",
#             "forename": "Joseph",
#             "surname": "Lobmeyr",
#             "occupations": "k. k. Hofglashändler"
#         },
#         {
#             "ID": "FranzLobmeyr",
#             "forename": "Franz",
#             "surname": "Lobmeyr",
#             "occupations": "k. k. Linienschiffs-Lieutenant"
#         },
#         {
#             "ID": "LouiseKralik",
#             "forename": "Louise",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "Lobmayr",
#             "death_date": "1905-10-03",
#             "idnos": "ID (WIKIDATA): Q133874636"
#         },
#         {
#             "ID": "HannsKralik",
#             "forename": "Hanns",
#             "surname": "Kralik von Meyrswalden"
#         },
#         {
#             "ID": "HeinrichKralikSen",
#             "forename": "Heinrich",
#             "surname": "Kralik von Meyrswalden",
#             "occupations": "Glasfabrikant",
#             "idnos": "URL (Wikipedia): https://de.wikipedia.org/wiki/Heinrich_Kralik_von_Meyrswalden_(Industrieller)"
#         },
#         {
#             "ID": "MathildeRath",
#             "forename": "Mathilde",
#             "surname": "Rath",
#             "surname maiden": "Lobmeyr"
#         },
#         {
#             "ID": "WilhelmKralik",
#             "forename": "Wilhelm",
#             "surname": "Kralik von Meyrswalden",
#             "occupations": "Glasfabriken-Besitzer",
#             "idnos": "ID (GND): 136539696; ID (WIKIDATA): Q2573745"
#         },
#         {
#             "ID": "LudwigKralik",
#             "forename": "Ludwig",
#             "surname": "Ritter Kralik von Meyrswalden",
#             "occupations": "Oberingenieur der Kaiser-Ferdinand-Nordbahn"
#         },
#         {
#             "ID": "HildegardLobmeyr",
#             "forename": "Hildegard",
#             "surname": "Lobmeyr",
#             "surname maiden": "von Stahlberg"
#         },
#         {
#             "ID": "AloisiaLobmeyr",
#             "forename": "Aloisia",
#             "surname": "Lobmeyr",
#             "surname maiden": "Dobratsky",
#             "death_date": "1864-01-26"
#         },
#         {
#             "ID": "CarlGerold",
#             "forename": "Carl",
#             "surname": "Gerold",
#             "occupations": "Buchdrucker",
#             "idnos": "ID (WGW): 19487; ID (GND): 133262871; ID (WIKIDATA): Q61995654"
#         },
#         {
#             "ID": "RudolfLobmeyr",
#             "forename": "Rudolf",
#             "surname": "Lobmeyr",
#             "occupations": "k. k. Bezirkshauptmann"
#         },
#         {
#             "ID": "AdolfLobmeyr",
#             "forename": "Adolf",
#             "surname": "Lobmeyr",
#             "occupations": "Oberinspektionsrat der Generalinspektion der österreichischen Eisenbahnen"
#         },
#         {
#             "ID": "OskarLobmeyr",
#             "forename": "Oskar",
#             "surname": "von Lobmeyr",
#             "occupations": "Vize-Präsident der küstenländischen Statthalterei",
#             "idnos": "ID (GND): 1157623174"
#         },
#         {
#             "ID": "LudwigLobmeyrJun",
#             "forename": "Ludwig",
#             "surname": "Lobmeyr",
#             "occupations": "k. k. Rittmeister"
#         },
#         {
#             "ID": "JennyLobmeyr",
#             "forename": "Jenny",
#             "surname": "Lobmeyr",
#             "surname maiden": "Ruße"
#         },
#         {
#             "ID": "MarieLobmeyr",
#             "forename": "Marie",
#             "surname": "Lobmeyr",
#             "surname maiden": "Steinhuber"
#         },
#         {
#             "ID": "EllyLobmeyr",
#             "forename": "Elly",
#             "surname": "von Lobmeyr",
#             "surname maiden": "Arbeßer von Rastburg"
#         },
#         {
#             "ID": "GretlLobmeyr",
#             "forename": "Gretl",
#             "surname": "Lobmeyr",
#             "surname maiden": "Handofsky"
#         },
#         {
#             "ID": "HermannSpaun",
#             "forename": "Hermann",
#             "surname": "von Spaun",
#             "occupations": "Geheimer Rat; k. k. Admiral",
#             "idnos": "ID (GND): 103544075X; URL (ÖBL): https://www.biographien.ac.at/oebl/oebl_S/Spaun_Hermann_1833_1919.xml"
#         },
#         {
#             "ID": "AugustRath",
#             "forename": "August",
#             "surname": "Rath",
#             "occupations": "kaiserlicher Rat"
#         },
#         {
#             "ID": "MarieSchönvonKreuzenau",
#             "forename": "Marie",
#             "surname": "Schön von Kreuzenau",
#             "surname maiden": "Rath"
#         },
#         {
#             "ID": "AugustRathjun",
#             "forename": "August",
#             "surname": "Rath jun.",
#             "occupations": "Großindustrieller"
#         },
#         {
#             "ID": "PaulRath",
#             "forename": "Paul",
#             "surname": "Rath",
#             "occupations": "k.k. Oberst"
#         },
#         {
#             "ID": "StefanRath",
#             "forename": "Stefan",
#             "surname": "Rath",
#             "occupations": "k. k. Oberleutnant i. V. d. E.; Gesellschafter der Firma J. & L. Lobmeyr"
#         },
#         {
#             "ID": "AdeleRath",
#             "forename": "Adele",
#             "surname": "Rath",
#             "surname maiden": "Wagenmann"
#         },
#         {
#             "ID": "KarlPichler",
#             "forename": "Karl",
#             "surname": "Pichler von Deeben",
#             "occupations": "k. k. Ministerialrat"
#         },
#         {
#             "ID": "MathildeKralik",
#             "forename": "Mathilde",
#             "surname": "Kralik von Meyrswalden",
#             "occupations": "Komponistin",
#             "idnos": "ID (WGW): 37789; ID (WIKIDATA): Q89972; ID (GND): 130214566; ID (PMB): 19659"
#         },
#         {
#             "ID": "AloisiaPichler",
#             "forename": "Louisa",
#             "surname": "Pichler von Deeben",
#             "surname maiden": "Kralik von Meyrswalden"
#         },
#         {
#             "ID": "MinnaKralik",
#             "forename": "Minna",
#             "surname": "Kralik von Meyrswalden"
#         },
#         {
#             "ID": "RichardKralik",
#             "forename": "Richard",
#             "surname": "Kralik von Meyrswalden",
#             "death_date": "1934-02-04",
#             "idnos": "ID (GND): 118777920; ID (WIKIDATA): Q1317482; ID (WGW): 16425; ID (PMB): 3731"
#         },
#         {
#             "ID": "MaiaKralik",
#             "forename": "Maia",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "von Flattich",
#             "idnos": "ID (GND): 116385863"
#         },
#         {
#             "ID": "EduardPichler",
#             "forename": "Eduard",
#             "surname": "Pichler von Deeben",
#             "occupations": "k. k. Ministerialrat; Sektionsrat im Eisenbahn-Ministerium"
#         },
#         {
#             "ID": "JosefBileg",
#             "forename": "Josef",
#             "surname": "Bileg",
#             "occupations": "Drucker"
#         },
#         {
#             "ID": "AgnesKralik",
#             "forename": "Agnes",
#             "surname": "Kralik von Meyrswalden"
#         },
#         {
#             "ID": "EduardSchmid",
#             "forename": "Eduard",
#             "surname": "Schmid",
#             "occupations": "Glasfabrikant",
#             "idnos": "URL (ÖBL): https://www.biographien.ac.at/oebl/oebl_S/Schmid_Josef-Eduard_1836_1910.xml; ID (GND): 1030547009"
#         },
#         {
#             "ID": "CarlKralik",
#             "forename": "Carl",
#             "surname": "Kralik von Meyrswalden"
#         },
#         {
#             "ID": "JosefTaschek",
#             "forename": "Josef",
#             "surname": "Taschek",
#             "idnos": "ID (WIKIDATA): Q8311993; URL (Wikipedia): https://de.wikipedia.org/wiki/Josef_Taschek"
#         },
#         {
#             "ID": "DietrichKralik",
#             "forename": "Dietrich",
#             "surname": "Kralik von Meyrswalden",
#             "occupations": "Universitätsprofessor",
#             "idnos": "ID (GND): 118777912; ID (WIKIDATA): Q1223897; ID (WGW): 16414"
#         },
#         {
#             "ID": "HeinrichKralik",
#             "forename": "Heinrich",
#             "surname": "Kralik von Meyrswalden",
#             "idnos": "ID (GND): 121829324; ID (WIKIDATA): Q1235353; ID (WGW): 16424"
#         },
#         {
#             "ID": "RodrichKralik",
#             "forename": "Rodrich",
#             "surname": "Kralik von Meyrswalden",
#             "occupations": "Landesgerichtsrat",
#             "idnos": "ID (GND): 11638610X"
#         },
#         {
#             "ID": "EdithPichler",
#             "forename": "Edith",
#             "surname": "Pichler von Deeben"
#         },
#         {
#             "ID": "IlsePichler",
#             "forename": "Ilse",
#             "surname": "Pichler von Deeben"
#         },
#         {
#             "ID": "HannahKralik",
#             "forename": "Hannah",
#             "surname": "Kralik von Meyerswalden"
#         },
#         {
#             "ID": "GretlKralik",
#             "forename": "Gretl",
#             "surname": "Kralik von Meyrswalden"
#         },
#         {
#             "ID": "LuiseKralik",
#             "forename": "Luise",
#             "surname": "Kralik von Meyrswalden"
#         },
#         {
#             "ID": "WinifredKralik",
#             "forename": "Winifred",
#             "surname": "Kralik",
#             "idnos": "ID (WGW): 37795; ID (WIKIDATA): Q59653649; ID (GND): 118643274"
#         },
#         {
#             "ID": "LeopoldKralik",
#             "forename": "Leopold",
#             "surname": "Kralik"
#         },
#         {
#             "ID": "ElfriedeKralik",
#             "forename": "Elfriede",
#             "surname": "Kralik"
#         },
#         {
#             "ID": "TheodorInnitzer",
#             "forename": "Theodor",
#             "surname": "Innitzer",
#             "idnos": "ID (GND): 118555634; ID (WIKIDATA): Q78988; ID (WGW): 13273; ID (PMB): 57443"
#         },
#         {
#             "ID": "RudolfWieser",
#             "forename": "Rudolf",
#             "surname": "Wieser"
#         },
#         {
#             "ID": "EdmundSteinbock",
#             "forename": "Edmund",
#             "surname": "Steinbock"
#         },
#         {
#             "ID": "AliceScarlates",
#             "forename": "Alice",
#             "surname": "Scarlates",
#             "idnos": "ID (WIKIDATA): Q52084077; ID (GND): 1228633460"
#         },
#         {
#             "ID": "EduardHauptmann",
#             "forename": "Eduard",
#             "surname": "Hauptmann"
#         },
#         {
#             "ID": "CarlHertlein",
#             "forename": "Carl",
#             "surname": "Hertlein"
#         },
#         {
#             "ID": "JuliusEpstein",
#             "forename": "Julius",
#             "surname": "Epstein",
#             "idnos": "URI (GND): https://d-nb.info/gnd/116652357; ID (WIKIDATA): Q79036"
#         },
#         {
#             "ID": "IreneZoepf",
#             "forename": "Irene",
#             "surname": "Zoepf",
#             "idnos": "URI (VIAF): http://viaf.org/viaf/66893083"
#         },
#         {
#             "ID": "Herder",
#             "forename": "Johann",
#             "surname": "Herder",
#             "idnos": "ID (WIKIDATA): Q155547; URI (GND): https://d-nb.info/gnd/118549553"
#         },
#         {
#             "ID": "Catull",
#             "forename": "Catull",
#             "idnos": "URI (GND): https://d-nb.info/gnd/118519719; ID (WIKIDATA): Q163079"
#         },
#         {
#             "ID": "JohannRathausky",
#             "forename": "Johann",
#             "surname": "Rathausky",
#             "idnos": "URI (GND): https://d-nb.info/gnd/1027435025"
#         },
#         {
#             "ID": "Sokrates",
#             "forename": "Sokrates",
#             "idnos": "ID (WIKIDATA): Q913"
#         },
#         {
#             "ID": "Ilse",
#             "forename": "Ilse"
#         },
#         {
#             "ID": "FranziskaTschampa",
#             "forename": "Franziska",
#             "surname": "Tschampa",
#             "idnos": "URI (GND): https://d-nb.info/gnd/1081510544"
#         },
#         {
#             "ID": "LulaGmeiner",
#             "forename": "Lula",
#             "surname": "Gmeiner",
#             "idnos": "URI (GND): https://d-nb.info/gnd/117212490; ID (WIKIDATA): Q1676668"
#         },
#         {
#             "ID": "FranzNaval",
#             "forename": "Franz",
#             "surname": "Naval",
#             "idnos": "URI (GND): https://d-nb.info/gnd/116266945; ID (WIKIDATA): Q87156"
#         },
#         {
#             "ID": "MarcellaPregi",
#             "forename": "Marcella",
#             "surname": "Pregi",
#             "idnos": "URI (GND): https://d-nb.info/gnd/116281588; ID (WIKIDATA): Q94761060"
#         },
#         {
#             "ID": "Angiline",
#             "forename": "Angiline"
#         },
#         {
#             "ID": "RudolphFitzner",
#             "forename": "Rudolph",
#             "surname": "Fitzner",
#             "idnos": "URI (GND): https://d-nb.info/gnd/116586540; ID (WIKIDATA): Q7377184"
#         },
#         {
#             "ID": "ErnstDohnany",
#             "forename": "Ernst",
#             "surname": "von Dohnányi",
#             "idnos": "URI (GND): https://d-nb.info/gnd/119110016; ID (WIKIDATA): Q78532"
#         },
#         {
#             "ID": "Beethoven",
#             "forename": "Ludwig",
#             "surname": "van Beethoven",
#             "idnos": "URI (GND): https://d-nb.info/gnd/118508288; ID (WIKIDATA): Q255"
#         },
#         {
#             "ID": "Mozart",
#             "forename": "Wolfgang",
#             "surname": "Mozart",
#             "idnos": "URI (GND): https://d-nb.info/gnd/118584596; ID (WIKIDATA): Q254"
#         },
#         {
#             "ID": "Haydn",
#             "forename": "Joseph",
#             "surname": "Haydn",
#             "idnos": "URI (GND): https://d-nb.info/gnd/118547356; ID (WIKIDATA): Q7349"
#         },
#         {
#             "ID": "LeoXIII",
#             "forename": "Leo",
#             "surname": "XIII",
#             "idnos": "ID (WIKIDATA): Q43922"
#         }
#     ]
# }
# C:\Users\annab\AppData\Local\Temp\ipykernel_11136\1623254778.py:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_person = df_person.applymap(preprocess_value)

# %% [markdown]
# ## **2.2. Place-json**

# %%
#CODE FOR JSON WITH EMPTY LINES
# Function to clean and preprocess data
#Created with u:ai
def preprocess_value(value):
    """
    Cleans and preprocesses a value:
    - Strips leading/trailing whitespace
    - Replaces empty strings or invalid data with None
    """
    if pd.isna(value) or str(value).strip() == '':
        return f""
    return str(value).strip()

#Replace english nouns with german translation
df_place['type']=df_place['type'].str.replace('street', 'Straße', regex=False)
df_place['type']=df_place['type'].str.replace('church', 'Kirche', regex=False)
df_place['type']=df_place['type'].str.replace('city', 'Stadt', regex=False)
df_place['type']=df_place['type'].str.replace('village', 'Dorf', regex=False)
df_place['type']=df_place['type'].str.replace('museum', 'Museum', regex=False)
df_place['type']=df_place['type'].str.replace('cemetery', 'Friedhof', regex=False)

# Apply preprocessing to all cells in the DataFrame
df_place = df_place.applymap(preprocess_value)

# Function to remove keys with None values
def remove_null_values(record):
    """
    Removes keys with None values from a dictionary.
    """
    return {key: value for key, value in record.items() if value is not None}

# Convert the DataFrame to a list of dictionaries and remove null values
place_records = [remove_null_values(record) for record in df_place.to_dict(orient='records')]

# Wrap the list of person records in a dictionary with a "data" key
place_json_data = {
    "data": place_records
}

# Write the JSON to a file
output_file_path = 'C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/json/place_index.json'
with open(output_file_path, 'w', encoding='utf-8') as json_file:
    json.dump(place_json_data, json_file, indent=4, ensure_ascii=False)

# Display the JSON structure (optional, for debugging)
print(json.dumps(place_json_data, indent=4, ensure_ascii=False))
# Out:
# {
#     "data": [
#         {
#             "ID": "Wien",
#             "name": "Wien",
#             "type": "Stadt",
#             "geo": "48.20849, 16.37208",
#             "Wikipedia": "",
#             "WIKIDATA": "Q1741",
#             "Geonames": "https://www.geonames.org/2761369/vienna.html",
#             "WGW": "",
#             "GND": "",
#             "Website": "Wien.html"
#         },
#         {
#             "ID": "Weimarerplatz_3",
#             "name": "Weimarerplatz 3",
#             "type": "Straße",
#             "geo": "48.233902622021546, 16.344070193512067",
#             "Wikipedia": "https://de.wikipedia.org/wiki/Richard-Kralik-Platz",
#             "WIKIDATA": "",
#             "Geonames": "",
#             "WGW": "26530",
#             "GND": "",
#             "Website": "Weimarerplatz_3.html"
#         },
#         {
#             "ID": "DöblingerFriedhof",
#             "name": "Döblinger Friedhof",
#             "type": "Friedhof",
#             "geo": "48.238719731402156, 16.328673269061063",
#             "Wikipedia": "https://de.wikipedia.org/wiki/D%C3%B6blinger_Friedhof",
#             "WIKIDATA": "Q1270909",
#             "Geonames": "",
#             "WGW": "6843",
#             "GND": "1233214810",
#             "Website": "DöblingerFriedhof.html"
#         },
#         {
#             "ID": "WähringerKirche",
#             "name": "Pfarrkirche heilige Gertraud und heiliger Laurentius",
#             "type": "Kirche",
#             "geo": "48.22621692059329, 16.34450228069556",
#             "Wikipedia": "https://de.wikipedia.org/wiki/W%C3%A4hringer_Pfarrkirche",
#             "WIKIDATA": "",
#             "Geonames": "",
#             "WGW": "3616",
#             "GND": "",
#             "Website": "WähringerKirche.html"
#         },
#         {
#             "ID": "Rosensteingasse_32",
#             "name": "Rosensteingasse 32",
#             "type": "Straße",
#             "geo": "48.21808403776477, 16.326086765349057",
#             "Wikipedia": "",
#             "WIKIDATA": "",
#             "Geonames": "",
#             "WGW": "",
#             "GND": "",
#             "Website": "Rosensteingasse_32.html"
#         },
#         {
#             "ID": "HernalserHauptstraße_81",
#             "name": "Hernalser Hauptstraße 81",
#             "type": "Straße",
#             "geo": "48.21845628508243, 16.328900153713658",
#             "Wikipedia": "",
#             "WIKIDATA": "",
#             "Geonames": "",
#             "WGW": "",
#             "GND": "",
#             "Website": "HernalserHauptstraße_81.html"
#         },
#         {
#             "ID": "EhrengrabKralik",
#             "name": "Ehrengrab Richard Kralik",
#             "type": "Friedhof",
#             "geo": "",
#             "Wikipedia": "",
#             "WIKIDATA": "",
#             "Geonames": "",
#             "WGW": "",
#             "GND": "",
#             "Website": "EhrengrabKralik.html"
#         },
#         {
#             "ID": "Stephansdom",
#             "name": "Dom- und Metropolitankirche zu St. Stephan",
#             "type": "Kirche",
#             "geo": "48.20854411963058, 16.373480666951327",
#             "Wikipedia": "",
#             "WIKIDATA": "",
#             "Geonames": "",
#             "WGW": "",
#             "GND": "",
#             "Website": "Stephansdom.html"
#         },
#         {
#             "ID": "StMarxerFriedhof",
#             "name": "St. Marxer Friedhof",
#             "type": "Friedhof",
#             "geo": "48.18402446536315, 16.4032053383651",
#             "Wikipedia": "",
#             "WIKIDATA": "",
#             "Geonames": "",
#             "WGW": "18057",
#             "GND": "4843295-7",
#             "Website": "StMarxerFriedhof.html"
#         },
#         {
#             "ID": "Weimar",
#             "name": "Weimar",
#             "type": "Stadt",
#             "geo": "50.9803, 11.32903",
#             "Wikipedia": "",
#             "WIKIDATA": "Q3955",
#             "Geonames": "",
#             "WGW": "",
#             "GND": "",
#             "Website": "Weimar.html"
#         },
#         {
#             "ID": "Zentralfriedhof",
#             "name": "Zentralfriedhof",
#             "type": "Friedhof",
#             "geo": "48.1514660511102, 16.438521926727077",
#             "Wikipedia": "https://de.wikipedia.org/wiki/Wiener_Zentralfriedhof",
#             "WIKIDATA": "Q240744",
#             "Geonames": "",
#             "WGW": "9327",
#             "GND": "4120093-7",
#             "Website": "Zentralfriedhof.html"
#         },
#         {
#             "ID": "GoldeggGasse_19",
#             "name": "Goldegg-Gasse 19",
#             "type": "Straße",
#             "geo": "48.18976066981652, 16.37695638069264",
#             "Wikipedia": "",
#             "WIKIDATA": "",
#             "Geonames": "",
#             "WGW": "",
#             "GND": "",
#             "Website": "GoldeggGasse_19.html"
#         },
#         {
#             "ID": "Favoritenstraße_27",
#             "name": "Favoritenstraße 27",
#             "type": "Straße",
#             "geo": "48.189747763641684, 16.372364634655163",
#             "Wikipedia": "",
#             "WIKIDATA": "",
#             "Geonames": "",
#             "WGW": "",
#             "GND": "",
#             "Website": "Favoritenstraße_27.html"
#         },
#         {
#             "ID": "Vorderbrühl",
#             "name": "Vorderbrühl",
#             "type": "Dorf",
#             "geo": "48.08284, 16.25874",
#             "Wikipedia": "",
#             "WIKIDATA": "Q114048876",
#             "Geonames": "https://www.geonames.org/2762284/vorderbruehl.html",
#             "WGW": "",
#             "GND": "",
#             "Website": "Vorderbrühl.html"
#         },
#         {
#             "ID": "Elisabethstraße_1",
#             "name": "Elisabethstraße 1",
#             "type": "Straße",
#             "geo": "48.201765590654134, 16.368675138366534",
#             "Wikipedia": "",
#             "WIKIDATA": "",
#             "Geonames": "",
#             "WGW": "",
#             "GND": "",
#             "Website": "Elisabethstraße_1.html"
#         },
#         {
#             "ID": "Augustinerkircher",
#             "name": "Augustinerkirche",
#             "type": "Kirche",
#             "geo": "48.20610677964904, 16.367669853712695",
#             "Wikipedia": "",
#             "WIKIDATA": "",
#             "Geonames": "",
#             "WGW": "28422",
#             "GND": "",
#             "Website": "Augustinerkircher.html"
#         },
#         {
#             "ID": "KärntnerStraße_21",
#             "name": "Kärntner Straße 21",
#             "type": "Straße",
#             "geo": "48.206327276134346, 16.371738011385606",
#             "Wikipedia": "",
#             "WIKIDATA": "",
#             "Geonames": "",
#             "WGW": "",
#             "GND": "",
#             "Website": "KärntnerStraße_21.html"
#         },
#         {
#             "ID": "Rennweg_91",
#             "name": "Rennweg 91",
#             "type": "Straße",
#             "geo": "48.19044582541425, 16.397931765346893",
#             "Wikipedia": "",
#             "WIKIDATA": "",
#             "Geonames": "",
#             "WGW": "",
#             "GND": "",
#             "Website": "Rennweg_91.html"
#         },
#         {
#             "ID": "ErdbergerKirche",
#             "name": "Peter-und-Paul-Kirche",
#             "type": "Kirche",
#             "geo": "48.200857294744246, 16.398227150471623",
#             "Wikipedia": "",
#             "WIKIDATA": "",
#             "Geonames": "",
#             "WGW": "14138",
#             "GND": "",
#             "Website": "ErdbergerKirche.html"
#         },
#         {
#             "ID": "KircheMödling",
#             "name": "Stadtpfarrkirche Mödling",
#             "type": "Kirche",
#             "geo": "48.085662256259745, 16.280088723318332",
#             "Wikipedia": "",
#             "WIKIDATA": "",
#             "Geonames": "",
#             "WGW": "",
#             "GND": "",
#             "Website": "KircheMödling.html"
#         },
#         {
#             "ID": "Eleonorenhain",
#             "name": "Eleonorenhain",
#             "type": "Dorf",
#             "geo": "48.9343471954487, 13.794896645500788",
#             "Wikipedia": "",
#             "WIKIDATA": "",
#             "Geonames": "",
#             "WGW": "",
#             "GND": "",
#             "Website": "Eleonorenhain.html"
#         },
#         {
#             "ID": "Annathal",
#             "name": "Annathal",
#             "type": "Dorf",
#             "geo": "48.87337398216413, 13.614796312599777",
#             "Wikipedia": "",
#             "WIKIDATA": "",
#             "Geonames": "",
#             "WGW": "",
#             "GND": "",
#             "Website": "Annathal.html"
#         },
#         {
#             "ID": "Zentralfriedhof_Halle1",
#             "name": "Zentralfriedhof Halle 1 Tor 2",
#             "type": "Friedhof",
#             "geo": "48.153249181929844, 16.442484911381403",
#             "Wikipedia": "https://de.wikipedia.org/wiki/Wiener_Zentralfriedhof",
#             "WIKIDATA": "Q240744",
#             "Geonames": "",
#             "WGW": "9327",
#             "GND": "4120093-7",
#             "Website": "Zentralfriedhof_Halle1.html"
#         },
#         {
#             "ID": "WeimarerStraße_89",
#             "name": "Weimarer Straße 89",
#             "type": "Straße",
#             "geo": "48.2367713611113, 16.344899553715038",
#             "Wikipedia": "",
#             "WIKIDATA": "",
#             "Geonames": "",
#             "WGW": "",
#             "GND": "",
#             "Website": "WeimarerStraße_89.html"
#         },
#         {
#             "ID": "Bendlgasse_24",
#             "name": "Bendlgasse 24",
#             "type": "Straße",
#             "geo": "48.17974233449344, 16.335147009528303",
#             "Wikipedia": "",
#             "WIKIDATA": "",
#             "Geonames": "",
#             "WGW": "",
#             "GND": "",
#             "Website": "Bendlgasse_24.html"
#         },
#         {
#             "ID": "Berlin",
#             "name": "Berlin",
#             "type": "Stadt",
#             "geo": "52.52437, 13.41053",
#             "Wikipedia": "",
#             "WIKIDATA": "Q1741",
#             "Geonames": "https://www.geonames.org/2950159/berlin.html",
#             "WGW": "",
#             "GND": "",
#             "Website": "Berlin.html"
#         },
#         {
#             "ID": "Seccession",
#             "name": "Seccession",
#             "type": "Museum",
#             "geo": "48.20041, 16.36542",
#             "Wikipedia": "",
#             "WIKIDATA": "Q265129",
#             "Geonames": "https://www.geonames.org/6354994/secession.html",
#             "WGW": "",
#             "GND": "",
#             "Website": "Seccession.html"
#         },
#         {
#             "ID": "Linz",
#             "name": "Linz",
#             "type": "Stadt",
#             "geo": "48.30639, 14.28611",
#             "Wikipedia": "",
#             "WIKIDATA": "Q41329",
#             "Geonames": "https://www.geonames.org/2772400/linz.html",
#             "WGW": "",
#             "GND": "",
#             "Website": "Linz.html"
#         }
#     ]
# }
# C:\Users\annab\AppData\Local\Temp\ipykernel_11136\4155585841.py:23: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_place = df_place.applymap(preprocess_value)

# %% [markdown]
# ## **2.3. Org-json**

# %%
#CODE FOR JSON WITH EMPTY LINES
# Function to clean and preprocess data
#Created with u:ai
def preprocess_value(value):
    """
    Cleans and preprocesses a value:
    - Strips leading/trailing whitespace
    - Replaces empty strings or invalid data with None
    """
    if pd.isna(value) or str(value).strip() == '':
        return f""
    return str(value).strip()

# Apply preprocessing to all cells in the DataFrame
df_org = df_org.applymap(preprocess_value)

# Function to remove keys with None values
def remove_null_values(record):
    """
    Removes keys with None values from a dictionary.
    """
    return {key: value for key, value in record.items() if value is not None}

#Replace english words with german translation
df_org['type']=df_org['type'].str.replace('manufactory', 'Manufaktur', regex=False)
df_org['type']=df_org['type'].str.replace('printer', 'Druckerei', regex=False)
df_org['type']=df_org['type'].str.replace('representativ', 'Vertretungsorgan', regex=False)
df_org['type']=df_org['type'].str.replace('cultural', 'Kulturelle Einrichtung', regex=False)
df_org['type']=df_org['type'].str.replace('paper', 'Papierwaren', regex=False)
df_org['type']=df_org['type'].str.replace('funeral', 'Bestattungsunternehmen', regex=False)
df_org['type']=df_org['type'].str.replace('transport', 'Verkehrswesen', regex=False)
df_org['type']=df_org['type'].str.replace('political', 'Politische Organisation', regex=False)
df_org['type']=df_org['type'].str.replace('press', 'Presse', regex=False)

# Convert the DataFrame to a list of dictionaries and remove null values
org_records = [remove_null_values(record) for record in df_org.to_dict(orient='records')]

# Wrap the list of person records in a dictionary with a "data" key
org_json_data = {
    "data": org_records
}

# Write the JSON to a file
output_file_path = 'C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/json/org_index.json'
with open(output_file_path, 'w', encoding='utf-8') as json_file:
    json.dump(org_json_data, json_file, indent=4, ensure_ascii=False)

# Display the JSON structure (optional, for debugging)
print(json.dumps(org_json_data, indent=4, ensure_ascii=False))
# Out:
# {
#     "data": [
#         {
#             "ID": "JLLobmeyr",
#             "name": "J. & L. Lobmeyr",
#             "type": "Manufaktur",
#             "idnos": "ID (WGW): 17959; ID (WIKIDATA): Q876883",
#             "Website": "JLLobmeyr.html"
#         },
#         {
#             "ID": "Gerold",
#             "name": "Gerold & Co",
#             "type": "Druckerei",
#             "idnos": "ID (WGW): 19514",
#             "Website": "Gerold.html"
#         },
#         {
#             "ID": "Herrenhaus",
#             "name": "Herrenhaus",
#             "type": "Vertretungsorgan",
#             "idnos": "ID (WGW): 12008",
#             "Website": "Herrenhaus.html"
#         },
#         {
#             "ID": "AkBild",
#             "name": "Akademie der bildenden Künste",
#             "type": "Kulturelle Einrichtung",
#             "idnos": "ID (WGW): 17555; ID (GND): 2003761-2; ID (WIKIDATA): Q414219",
#             "Website": "AkBild.html"
#         },
#         {
#             "ID": "GenossenschaftKünstler",
#             "name": "Genossenschaft der bildenden Künstler Wiens",
#             "type": "Kulturelle Einrichtung",
#             "idnos": "ID (WGW): 25052; ID (GND): 2100204-6; ID (WIKIDATA): Q284902",
#             "Website": "GenossenschaftKünstler.html"
#         },
#         {
#             "ID": "Schillerstiftung",
#             "name": "Deutsche Schillerstiftung",
#             "type": "Kulturelle Einrichtung",
#             "idnos": "ID (GND): 5187203-1",
#             "Website": "Schillerstiftung.html"
#         },
#         {
#             "ID": "TheyerHartmut",
#             "name": "THEYER & HARDTMUTH",
#             "type": "Papierwaren",
#             "idnos": "ID (WGW): 46454",
#             "Website": "TheyerHartmut.html"
#         },
#         {
#             "ID": "StädtischeLeichenbestattung",
#             "name": "Städtische Leichenbestattung",
#             "type": "Bestattungsunternehmen",
#             "idnos": "",
#             "Website": "StädtischeLeichenbestattung.html"
#         },
#         {
#             "ID": "DruckBileg",
#             "name": "Josef Bileg",
#             "type": "Druckerei",
#             "idnos": "",
#             "Website": "DruckBileg.html"
#         },
#         {
#             "ID": "GeneralinspektionEisenbahn",
#             "name": "Generalinspektion der österreichischen Eisenbahnen",
#             "type": "Verkehrswesen",
#             "idnos": "",
#             "Website": "GeneralinspektionEisenbahn.html"
#         },
#         {
#             "ID": "Statthalterei",
#             "name": "Küstenländische Statthalterei",
#             "type": "Politische Organisation",
#             "idnos": "",
#             "Website": "Statthalterei.html"
#         },
#         {
#             "ID": "Enterprisefunebres",
#             "name": "Entreprise des pompes funèbres",
#             "type": "Bestattungsunternehmen",
#             "idnos": "",
#             "Website": "Enterprisefunebres.html"
#         },
#         {
#             "ID": "Bärenhöhle",
#             "name": "Bärenhöhle",
#             "type": "Politische Organisation",
#             "idnos": "ID (WGW): 42579",
#             "Website": "Bärenhöhle.html"
#         },
#         {
#             "ID": "Nordbahn",
#             "name": "Kaiser-Ferdinands-Nordbahn",
#             "type": "Verkehrswesen",
#             "idnos": "URL (Wikipedia): https://de.wikipedia.org/wiki/Kaiser_Ferdinands-Nordbahn; ID (WGW): 21891; ID (WIKIDATA): Q352763; ID (GND): 4276204-2",
#             "Website": "Nordbahn.html"
#         },
#         {
#             "ID": "EisenbahnMinisterium",
#             "name": "Eisenbahnen-Ministerium",
#             "type": "Politische Organisation",
#             "idnos": "URL (Wikipedia): https://de.wikipedia.org/wiki/K.k._Eisenbahnministerium",
#             "Website": "EisenbahnMinisterium.html"
#         },
#         {
#             "ID": "BestattungPayer",
#             "name": "Payer, Schmutzer & Co",
#             "type": "Bestattungsunternehmen",
#             "idnos": "",
#             "Website": "BestattungPayer.html"
#         },
#         {
#             "ID": "Lischkar",
#             "name": "Lischkar & Co",
#             "type": "Druckerei",
#             "idnos": "",
#             "Website": "Lischkar.html"
#         },
#         {
#             "ID": "Vaterland",
#             "name": "Vaterland",
#             "type": "Presse",
#             "idnos": "ID (WIKIDATA): Q125847075",
#             "Website": "Vaterland.html"
#         },
#         {
#             "ID": "FreiePresse",
#             "name": "Neue Freie Presse",
#             "type": "Presse",
#             "idnos": "ID (WIKIDATA): Q2919142",
#             "Website": "FreiePresse.html"
#         },
#         {
#             "ID": "Extrablatt",
#             "name": "Illustrirtes Wiener Extrablatt",
#             "type": "Presse",
#             "idnos": "ID (WIKIDATA): Q1658926",
#             "Website": "Extrablatt.html"
#         },
#         {
#             "ID": "MeyrsNeffe",
#             "name": "Meyr's Neffe",
#             "type": "Manufaktur",
#             "idnos": "ID (WIKIDATA): Q1926388",
#             "Website": "MeyrsNeffe.html"
#         },
#         {
#             "ID": "WienerKonservatorium",
#             "name": "Wiener Konservatorium",
#             "type": "Kulturelle Einrichtung",
#             "idnos": "ID (WIKIDATA): Q28864370",
#             "Website": "WienerKonservatorium.html"
#         }
#     ]
# }
# C:\Users\annab\AppData\Local\Temp\ipykernel_11136\106211850.py:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_org = df_org.applymap(preprocess_value)

# %% [markdown]
# ## **2.4. Relation json**

# %%
#CODE FOR JSON WITH EMPTY LINES
# Function to clean and preprocess data
#Created with u:ai
def preprocess_value(value):
    """
    Cleans and preprocesses a value:
    - Strips leading/trailing whitespace
    - Replaces empty strings or invalid data with None
    """
    if pd.isna(value) or str(value).strip() == '':
        return None
    return str(value).strip()

# Apply preprocessing to all cells in the DataFrame
df_relation = df_relations.applymap(preprocess_value)

# Function to remove keys with None values
def remove_null_values(record):
    """
    Removes keys with None values from a dictionary.
    """
    return {key: value for key, value in record.items() if value is not None}

# Convert the DataFrame to a list of dictionaries and remove null values
relation_records = [remove_null_values(record) for record in df_relation.to_dict(orient='records')]

# Wrap the list of person records in a dictionary with a "data" key
relation_json_data = {
    "data": relation_records
}

# Write the JSON to a file
output_file_path = 'C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/json/relation_index.json'
with open(output_file_path, 'w', encoding='utf-8') as json_file:
    json.dump(relation_json_data, json_file, indent=4, ensure_ascii=False)

# Display the JSON structure (optional, for debugging)
print(json.dumps(relation_json_data, indent=4, ensure_ascii=False))
# Out:
# {
#     "data": [
#         {
#             "name": "parent",
#             "active": "August Rath",
#             "passive": "Marie Sch Kreuzenau, August Rathjun, Paul Rath, Stefan Rath"
#         },
#         {
#             "name": "parent",
#             "active": "Aloisia Lobmeyr",
#             "passive": "Joseph Lobmeyr, Ludwig Lobmeyr, Franz Lobmeyr, Louise Kralik, Mathilde Rath"
#         },
#         {
#             "name": "parent",
#             "active": "Louise Kralik",
#             "passive": "Richard Kralik, Mathilde Kralik, Aloisia Pichler"
#         },
#         {
#             "name": "parent",
#             "active": "Maia Kralik",
#             "passive": "Dietrich Kralik, Heinrich Kralik, Rodrich Kralik"
#         },
#         {
#             "name": "parent",
#             "active": "Richard Kralik",
#             "passive": "Dietrich Kralik, Heinrich Kralik, Rodrich Kralik"
#         },
#         {
#             "name": "parent",
#             "active": "Aloisia Pichler",
#             "passive": "Ilse Pichler, Edith Pichler"
#         },
#         {
#             "name": "parent",
#             "active": "Eduard Pichler",
#             "passive": "Ilse Pichler, Edith Pichler"
#         },
#         {
#             "name": "grandparent",
#             "active": "Louise Kralik",
#             "passive": "Dietrich Kralik, Heinrich Kralik, Rodrich Kralik, Ilse Pichler, Edith Pichler"
#         },
#         {
#             "name": "grandparent",
#             "active": "Maia Kralik",
#             "passive": "Winifred Kralik, Leopold Kralik, Elfriede Kralik"
#         },
#         {
#             "name": "grandparent",
#             "active": "Richard Kralik",
#             "passive": "Winifred Kralik, Leopold Kralik, Elfriede Kralik"
#         },
#         {
#             "name": "sibling",
#             "mutual": "Louise Kralik, Ludwig Lobmeyr, Mathilde Rath"
#         },
#         {
#             "name": "sibling",
#             "mutual": "Rudolf Lobmeyr, Adolf Lobmeyr, Oskar Lobmeyr, Ludwig Lobmeyr Jun"
#         },
#         {
#             "name": "sibling",
#             "mutual": "Marie Sch Kreuzenau, August Rathjun, Paul Rath, Stefan Rath"
#         },
#         {
#             "name": "sibling",
#             "mutual": "Richard Kralik, Mathilde Kralik, Aloisia Pichler"
#         },
#         {
#             "name": "sibling",
#             "mutual": "Joseph Lobmeyr, Ludwig Lobmeyr, Franz Lobmeyr, Louise Kralik, Mathilde Rath"
#         },
#         {
#             "name": "sibling",
#             "mutual": "Heinrich Kralik, Rodrich Kralik, Dietrich Kralik"
#         },
#         {
#             "name": "uncle",
#             "active": "Ludwig Lobmeyr",
#             "passive": "Rudolf Lobmeyr, Adolf Lobmeyr, Oskar Lobmeyr, Ludwig Lobmeyr Jun, Marie Sch Kreuzenau, August Rathjun, Paul Rath, Stefan Rath, Richard Kralik, Mathilde Kralik, Aloisia Pichler"
#         },
#         {
#             "name": "uncle",
#             "active": "Ludwig Kralik",
#             "passive": "Dietrich Kralik, Heinrich Kralik, Rodrich Kralik, Ilse Pichler, Edith Pichler"
#         },
#         {
#             "name": "spouse",
#             "mutual": "Louise Kralik, Wilhelm Kralik"
#         },
#         {
#             "name": "spouse",
#             "mutual": "Hildegard Lobmeyr, Franz Lobmeyr"
#         },
#         {
#             "name": "spouse",
#             "mutual": "Maia Kralik, Richard Kralik"
#         },
#         {
#             "name": "spouse",
#             "mutual": "Aloisia Pichler, Eduard Pichler"
#         },
#         {
#             "name": "partner",
#             "mutual": "Alice Scarlates, Mathilde Kralik"
#         }
#     ]
# }
# C:\Users\annab\AppData\Local\Temp\ipykernel_12316\160365434.py:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_relation = df_relations.applymap(preprocess_value)

# %% [markdown]
# # **3. Metadaten (letters, etc.) to json**

# %% [markdown]
# ## **3.1. Opening files**

# %%
#Path to directory
path_briefe="C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/metadaten/metadaten_briefe.xlsx"
path_totenzettel="C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/metadaten/metadaten_totenzettel.xlsx"
path_manuskripte="C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/metadaten/metadaten_manuskripte.xlsx"

# %%
#Excel to pd
df_briefe=pd.read_excel(path_briefe)
df_totenzettel=pd.read_excel(path_totenzettel)
df_manuskripte=pd.read_excel(path_manuskripte)

# %% [markdown]
# ## **3.2. Briefe to json**

# %%
#Originally created with u:ai, but adapted and changed manually
#Convert df to a list of dictionaries
briefe_records=df_briefe.to_dict(orient='records')

#Wrap list in data key
briefe_json_data = {
    "data": briefe_records
}

#Write JSON to file
output_file_path='C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/json/briefe_index.json'
with open(output_file_path, 'w', encoding='utf-8') as json_file:
    json.dump(briefe_json_data, json_file, indent=4, ensure_ascii=False)

# Display the JSON structure (optional, for debugging)
#print(json.dumps(briefe_json_data, indent=4, ensure_ascii=False))

# %% [markdown]
# ## **3.3. Totenzettel to json**

# %%
#Originally created with u:ai, but adapted and changed manually
#Convert df to a list of dictionaries
toten_records=df_totenzettel.to_dict(orient='records')

#Wrap list in data key
toten_json_data = {
    "data": toten_records
}

#Write JSON to file
output_file_path='C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/json/toten_index.json'
with open(output_file_path, 'w', encoding='utf-8') as json_file:
    json.dump(toten_json_data, json_file, indent=4, ensure_ascii=False)

# %% [markdown]
# ## **3.4. Manuskript to json**

# %%
#Originally created with u:ai, but adapted and changed manually
#Convert df to a list of dictionaries
manuskripte_records=df_manuskripte.to_dict(orient='records')

#Wrap list in data key
manuskripte_json_data = {
    "data": manuskripte_records
}

#Write JSON to file
output_file_path='C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/json/manuskript_index.json'
with open(output_file_path, 'w', encoding='utf-8') as json_file:
    json.dump(manuskripte_json_data, json_file, indent=4, ensure_ascii=False)

# %% [markdown]
# # **4. Individual webpages**

# %% [markdown]
# ## **4.1. Webpages person**

# %%
data = df_person.copy()

# Create output directory for the generated HTML files
output_dir = "C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/html/personen"
os.makedirs(output_dir, exist_ok=True)

# %%
# HTML template for the webpage
html_template = """<!DOCTYPE HTML>
<html>
    <head>
        <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
        <title>Edition Mathilde Kralik - {title}</title>
        <link rel="stylesheet" type="text/css" href="../../css/menu_bar.css">
        <link rel="stylesheet" type="text/css" href="../../css/eintrag.css">
        <link rel="preconnect" href="https://fonts.googleapis.com">
        <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin="anonymous">
        <link href="https://fonts.googleapis.com/css2?family=Merriweather:ital,opsz,wght@0,18..144,300..900&amp;1,18..144,300..900&amp;family=Montserrat:ital,wght@0,100..900&amp;1,100..900&amp;display=swap" rel="stylesheet">
    </head>
    <body>
        <!-- Navigation bar -->
                 <nav class="topnav" aria-label="Main Navigation">
                     <a href="../../index.html">Menü</a>
                     
                     <!-- Submenu for documents -->
                     <div class="subnav">
                         <div class="nav-toggle">Dokumente</div>
                         <div class="subnav-content" aria-label="Submenu">
                             <a href="../Briefe.html">Briefe</a>
                             <a href="../Manuskript.html">Manuskripte</a>
                             <a href="../Totenzettel.html">Totenzettel</a>
                         </div>
                     </div>
                     
                     <!-- Submenu for Entities -->
                     <div class="subnav">
                         <div class="nav-toggle">Verzeichnis</div>
                         <div class="subnav-content" aria-label="Submenu">
                             <a href="../Personen.html">Personen</a>
                             <a href="../Orte.html">Orte</a>
                             <a href="../Org.html">Organisationen</a>
                         </div>
                     </div>
                     
                     <!-- Submenu for Visualisations -->
                     <div class="subnav">
                         <div class="nav-toggle">Visualisierungen</div>
                         <div class="subnav-content" aria-label="Submenu">
                             <a href="../Vis_Orte.html">Orte</a>
                             <a href="../Vis_Personen.html">Personennetzwerk</a>
                         </div>
                     </div>
                     
                     <!-- Submenu for Mathilde Kralik -->
                     <div class="subnav">
                         <div class="nav-toggle">Mathilde Kralik</div>
                         <div class="subnav-content" aria-label="Mathilde Kralik Submenu">
                             <a href="../Ressourcen.html">Ressourcen</a>
                         </div>
                     </div>
                     
                     <!-- Submenu for Edition -->
                     <div class="subnav">
                         <div class="nav-toggle">Über die Edition</div>
                         <div class="subnav-content" aria-label="Edition Submenu">
                             <a href="../Projekt.html">Projekt</a>
                             <a href="../Transkription.html">Transkription</a>
                             <a href="https://github.com/baueranna/mathilde_kralik.git" target="_blank" rel="noopener noreferrer">Github</a>
                         </div>
                     </div>
                 </nav>
        <main>
            <h1>{title}</h1>
            <table>
                {table_rows}
            </table>
        </main>
        <script src="../../js/menu_bar.js"></script>
    </body>
</html>
"""

# %%
# Function to generate table rows dynamically based on non-empty data
def generate_table_rows(row):
    table_rows = ""
    if row.get("forename"):
        table_rows += f"<tr><th>Vorname</th><td>{row['forename']}</td></tr>\n"
    if row.get("surname"):
        table_rows += f"<tr><th>Nachname</th><td>{row['surname']}</td></tr>\n"
    if row.get("surname maiden"):
        table_rows += f"<tr><th>Geburtsname</th><td>{row['surname maiden']}</td></tr>\n"
    if row.get("death_date"):
        table_rows += f"<tr><th>Sterbedatum</th><td>{row['death_date']}</td></tr>\n"
    if row.get("occupations"):
        table_rows += f"<tr><th>Beruf</th><td>{row['occupations']}</td></tr>\n"
    if row.get("affiliations"):
        table_rows += f"<tr><th>Mitgliedschaft</th><td>{row['affiliations']}</td></tr>\n"
    if row.get("Wikidata"):
        table_rows += f"<tr><th>WIKIDATA</th><td><a href='https://www.wikidata.org/wiki/{row['Wikidata']}' class='info'>{row['Wikidata']}</a></td></tr>\n"
    if row.get("WGW"):
        table_rows += f"<tr><th>WGW</th><td><a href='https://www.geschichtewiki.wien.gv.at/Special:URIResolver/?curid={row['WGW']}' class='info'>{row['WGW']}</a></td></tr>\n"
    return table_rows
    if row.get("GND"):
        table_rows += f"<tr><th>GND</th><td><a href='https://d-nb.info/gnd/{row['GND']}' class='info'>{row['GND']}</a></td></tr>\n"
    return table_rows
    if row.get("Wikipedia"):
        table_rows += f"<tr><th>Wikipedia</th><td><a href='{row['Wikipedia']}' class='info'>{row['forename']} {row['surname']}</a></td></tr>\n"
    return table_rows
    if row.get("VIAF"):
        table_rows += f"<tr><th>VIAF</th><td><a href='https://viaf.org/de/viaf/{row['VIAF']}' class='info'>{row['VIAF']}</a></td></tr>\n"
    return table_rows
    if row.get("ÖBL"):
        table_rows += f"<tr><th>ÖBL</th><td><a href='{row['ÖBL']}' class='info'>{row['forename']} {row['surname']}</a></td></tr>\n"
    return table_rows
    if row.get("PMB"):
        table_rows += f"<tr><th>PMB</th><td><a href='https://pmb.acdh.oeaw.ac.at/apis/entities/entity/person/{row['PMB']}' class='info'>{row['PMB']}</a></td></tr>\n"
    return table_rows

# Iterate through each row in the CSV and generate an HTML file
for index, row in data.iterrows():
    # Generate the table rows dynamically
    table_rows = generate_table_rows(row)
    
    # Generate the HTML content
    html_content = html_template.format(
        title=f"{row.get('forename', '')} {row.get('surname', '')}",
        table_rows=table_rows
    )
    
    # Save the HTML file
    website = row.get("Website", "default.html")
    output_file = os.path.join(output_dir, website)
    with open(output_file, "w", encoding="utf-8") as f:
        f.write(html_content)

print(f"HTML files have been generated in the '{output_dir}' directory.")
# Out:
# HTML files have been generated in the 'C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/html/personen' directory.

# %% [markdown]
# ## **4.2. Webpage places**

# %%
data2 = df_place.copy()

#Replace english nouns with german translation
data2['type']=data2['type'].str.replace('street', 'Straße', regex=False)
data2['type']=data2['type'].str.replace('church', 'Kirche', regex=False)
data2['type']=data2['type'].str.replace('city', 'Stadt', regex=False)
data2['type']=data2['type'].str.replace('village', 'Dorf', regex=False)
data2['type']=data2['type'].str.replace('museum', 'Museum', regex=False)
data2['type']=data2['type'].str.replace('cemetery', 'Friedhof', regex=False)

# Create output directory for the generated HTML files
output_dir2 = "C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/html/orte"
os.makedirs(output_dir2, exist_ok=True)

# %%
# HTML template for the webpage
html_template = """<!DOCTYPE HTML>
<html>
    <head>
        <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
        <title>Edition Mathilde Kralik - {title}</title>
        <link rel="stylesheet" type="text/css" href="../../css/menu_bar.css">
        <link rel="stylesheet" type="text/css" href="../../css/eintrag.css">
        <link rel="preconnect" href="https://fonts.googleapis.com">
        <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin="anonymous">
        <link href="https://fonts.googleapis.com/css2?family=Merriweather:ital,opsz,wght@0,18..144,300..900&amp;1,18..144,300..900&amp;family=Montserrat:ital,wght@0,100..900&amp;1,100..900&amp;display=swap" rel="stylesheet">
    </head>
    <body>
       <!-- Navigation bar -->
                 <nav class="topnav" aria-label="Main Navigation">
                     <a href="../../index.html">Menü</a>
                     
                     <!-- Submenu for documents -->
                     <div class="subnav">
                         <div class="nav-toggle">Dokumente</div>
                         <div class="subnav-content" aria-label="Submenu">
                             <a href="../Briefe.html">Briefe</a>
                             <a href="../Manuskript.html">Manuskripte</a>
                             <a href="../Totenzettel.html">Totenzettel</a>
                         </div>
                     </div>
                     
                     <!-- Submenu for Entities -->
                     <div class="subnav">
                         <div class="nav-toggle">Verzeichnis</div>
                         <div class="subnav-content" aria-label="Submenu">
                             <a href="../Personen.html">Personen</a>
                             <a href="../Orte.html">Orte</a>
                             <a href="../Org.html">Organisationen</a>
                         </div>
                     </div>
                     
                     <!-- Submenu for Visualisations -->
                     <div class="subnav">
                         <div class="nav-toggle">Visualisierungen</div>
                         <div class="subnav-content" aria-label="Submenu">
                             <a href="../Vis_Orte.html">Orte</a>
                             <a href="../Vis_Personen.html">Personennetzwerk</a>
                         </div>
                     </div>
                     
                     <!-- Submenu for Mathilde Kralik -->
                     <div class="subnav">
                         <div class="nav-toggle">Mathilde Kralik</div>
                         <div class="subnav-content" aria-label="Mathilde Kralik Submenu">
                             <a href="../Ressourcen.html">Ressourcen</a>
                         </div>
                     </div>
                     
                     <!-- Submenu for Edition -->
                     <div class="subnav">
                         <div class="nav-toggle">Über die Edition</div>
                         <div class="subnav-content" aria-label="Edition Submenu">
                             <a href="../Projekt.html">Projekt</a>
                             <a href="../Transkription.html">Transkription</a>
                             <a href="https://github.com/baueranna/mathilde_kralik.git" target="_blank" rel="noopener noreferrer">Github</a>
                         </div>
                     </div>
                 </nav>
        <main>
            <h1>{title}</h1>
            <table>
                {table_rows}
            </table>
        </main>
        <script src="../../js/menu_bar.js"></script>
    </body>
</html>
"""

# %%
# Function to generate table rows dynamically based on non-empty data
def generate_table_rows(row):
    table_rows = ""
    if row.get("name"):
        table_rows += f"<tr><th>Name</th><td>{row['name']}</td></tr>\n"
    if row.get("type"):
        table_rows += f"<tr><th>Art</th><td>{row['type']}</td></tr>\n"
    if row.get("geo"):
        table_rows += f"<tr><th>Geodaten</th><td>{row['geo']}</td></tr>\n"
    if row.get("WIKIDATA"):
        table_rows += f"<tr><th>WIKIDATA</th><td><a href='https://www.wikidata.org/wiki/{row['WIKIDATA']}' class='info'>{row['WIKIDATA']}</a></td></tr>\n"
    if row.get("WGW"):
        table_rows += f"<tr><th>WGW</th><td><a href='https://www.geschichtewiki.wien.gv.at/Special:URIResolver/?curid={row['WGW']}' class='info'>{row['WGW']}</a></td></tr>\n"
    return table_rows
    if row.get("GND"):
        table_rows += f"<tr><th>GND</th><td><a href='https://d-nb.info/gnd/{row['GND']}' class='info'>{row['GND']}</a></td></tr>\n"
    return table_rows
    if row.get("Wikipedia"):
        table_rows += f"<tr><th>Wikipedia</th><td><a href='{row['Wikipedia']}' class='info'>{row['Wikipedia']}</a></td></tr>\n"
    return table_rows
    if row.get("Geonames"):
        table_rows += f"<tr><th>Geonames</th><td><a href='{row['Geonames']}' class='info'>{row['Geonames']}</a></td></tr>\n"
    return table_rows

# Iterate through each row in the CSV and generate an HTML file
for index, row in data2.iterrows():
    # Generate the table rows dynamically
    table_rows = generate_table_rows(row)
    
    # Generate the HTML content
    html_content = html_template.format(
        title=f"{row.get('name', '')}",
        table_rows=table_rows
    )
    
    # Save the HTML file
    website = row.get("Website", "default.html")
    output_file = os.path.join(output_dir2, website)
    with open(output_file, "w", encoding="utf-8") as f:
        f.write(html_content)

print(f"HTML files have been generated in the '{output_dir2}' directory.")
# Out:
# HTML files have been generated in the 'C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/html/orte' directory.

# %% [markdown]
# ## **4.3. Website org**

# %%
data3 = df_org.copy()

#Replace english words with german translation
data3['type']=data3['type'].str.replace('manufactory', 'Manufaktur', regex=False)
data3['type']=data3['type'].str.replace('printer', 'Druckerei', regex=False)
data3['type']=data3['type'].str.replace('representativ', 'Vertretungsorgan', regex=False)
data3['type']=data3['type'].str.replace('cultural', 'Kulturelle Einrichtung', regex=False)
data3['type']=data3['type'].str.replace('paper', 'Papierwaren', regex=False)
data3['type']=data3['type'].str.replace('funeral', 'Bestattungsunternehmen', regex=False)
data3['type']=data3['type'].str.replace('transport', 'Verkehrswesen', regex=False)
data3['type']=data3['type'].str.replace('political', 'Politische Organisation', regex=False)
data3['type']=data3['type'].str.replace('press', 'Presse', regex=False)

# Create output directory for the generated HTML files
output_dir3 = "C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/html/org"
os.makedirs(output_dir3, exist_ok=True)

# %%
# HTML template for the webpage
html_template = """<!DOCTYPE HTML>
<html>
    <head>
        <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
        <title>Edition Mathilde Kralik - {title}</title>
        <link rel="stylesheet" type="text/css" href="../../css/menu_bar.css">
        <link rel="stylesheet" type="text/css" href="../../css/eintrag.css">
        <link rel="preconnect" href="https://fonts.googleapis.com">
        <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin="anonymous">
        <link href="https://fonts.googleapis.com/css2?family=Merriweather:ital,opsz,wght@0,18..144,300..900&amp;1,18..144,300..900&amp;family=Montserrat:ital,wght@0,100..900&amp;1,100..900&amp;display=swap" rel="stylesheet">
    </head>
    <body>
        <!-- Navigation bar -->
                 <nav class="topnav" aria-label="Main Navigation">
                     <a href="../../index.html">Menü</a>
                     
                     <!-- Submenu for documents -->
                     <div class="subnav">
                         <div class="nav-toggle">Dokumente</div>
                         <div class="subnav-content" aria-label="Submenu">
                             <a href="../Briefe.html">Briefe</a>
                             <a href="../Manuskript.html">Manuskripte</a>
                             <a href="../Totenzettel.html">Totenzettel</a>
                         </div>
                     </div>
                     
                     <!-- Submenu for Entities -->
                     <div class="subnav">
                         <div class="nav-toggle">Verzeichnis</div>
                         <div class="subnav-content" aria-label="Submenu">
                             <a href="../Personen.html">Personen</a>
                             <a href="../Orte.html">Orte</a>
                             <a href="../Org.html">Organisationen</a>
                         </div>
                     </div>
                     
                     <!-- Submenu for Visualisations -->
                     <div class="subnav">
                         <div class="nav-toggle">Visualisierungen</div>
                         <div class="subnav-content" aria-label="Submenu">
                             <a href="../Vis_Orte.html">Orte</a>
                             <a href="../Vis_Personen.html">Personennetzwerk</a>
                         </div>
                     </div>
                     
                     <!-- Submenu for Mathilde Kralik -->
                     <div class="subnav">
                         <div class="nav-toggle">Mathilde Kralik</div>
                         <div class="subnav-content" aria-label="Mathilde Kralik Submenu">
                             <a href="../Ressourcen.html">Ressourcen</a>
                         </div>
                     </div>
                     
                     <!-- Submenu for Edition -->
                     <div class="subnav">
                         <div class="nav-toggle">Über die Edition</div>
                         <div class="subnav-content" aria-label="Edition Submenu">
                             <a href="../Projekt.html">Projekt</a>
                             <a href="../Transkription.html">Transkription</a>
                             <a href="https://github.com/baueranna/mathilde_kralik.git" target="_blank" rel="noopener noreferrer">Github</a>
                         </div>
                     </div>
                 </nav>
        <main>
            <h1>{title}</h1>
            <table>
                {table_rows}
            </table>
        </main>
        <script src="../../js/menu_bar.js"></script>
    </body>
</html>
"""

# %%
# Function to generate table rows dynamically based on non-empty data
def generate_table_rows(row):
    table_rows = ""
    if row.get("name"):
        table_rows += f"<tr><th>Name</th><td>{row['name']}</td></tr>\n"
    if row.get("type"):
        table_rows += f"<tr><th>Art</th><td>{row['type']}</td></tr>\n"
    if row.get("WIKIDATA"):
        table_rows += f"<tr><th>WIKIDATA</th><td><a href='https://www.wikidata.org/wiki/{row['WIKIDATA']}' class='info'>{row['WIKIDATA']}</a></td></tr>\n"
    if row.get("WGW"):
        table_rows += f"<tr><th>WGW</th><td><a href='https://www.geschichtewiki.wien.gv.at/Special:URIResolver/?curid={row['WGW']}' class='info'>{row['WGW']}</a></td></tr>\n"
    return table_rows
    if row.get("GND"):
        table_rows += f"<tr><th>GND</th><td><a href='https://d-nb.info/gnd/{row['GND']}' class='info'>{row['GND']}</a></td></tr>\n"
    return table_rows
    if row.get("Wikipedia"):
        table_rows += f"<tr><th>Wikipedia</th><td><a href='{row['Wikipedia']}' class='info'>{row['Wikipedia']}</a></td></tr>\n"
    return table_rows

# Iterate through each row in the CSV and generate an HTML file
for index, row in data3.iterrows():
    # Generate the table rows dynamically
    table_rows = generate_table_rows(row)
    
    # Generate the HTML content
    html_content = html_template.format(
        title=f"{row.get('name', '')}",
        table_rows=table_rows
    )
    
    # Save the HTML file
    website = row.get("Website", "default.html")
    output_file = os.path.join(output_dir3, website)
    with open(output_file, "w", encoding="utf-8") as f:
        f.write(html_content)

print(f"HTML files have been generated in the '{output_dir3}' directory.")
# Out:
# HTML files have been generated in the 'C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/html/org' directory.

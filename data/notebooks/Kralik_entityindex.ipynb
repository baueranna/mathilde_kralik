# %% [markdown]
# # **1. Libaries and files**

# %%
#Importing libraries
import os
import glob
import re
import json
from bs4 import BeautifulSoup, Tag, NavigableString
import xml.etree.ElementTree as ET
from xml.dom import minidom
from xml.etree.ElementTree import Element
from xml.etree.ElementTree import SubElement
import pandas as pd
from lxml import etree

# %%
#Change accordingly
file_path_index="C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/tei/Index/index_person_place_org.xml"

# %% [markdown]
# # **2. Creating csv with index**

# %%
#Accessing index
tree = etree.parse(file_path_index)
root = tree.getroot()

# %%
# Define the TEI namespace
ns = {'tei': 'http://www.tei-c.org/ns/1.0'}

# %% [markdown]
# ## **2.1. Index person**

# %%
#Created with the help of u:ai
# Extract <person> elements
persons = root.xpath('//tei:listPerson/tei:person', namespaces=ns)
print(f"Number of <person> elements found: {len(persons)}")

# Extract data
data = []
for person in persons:
    person_data = {}
    # Extract xml:id
    person_data['ID'] = person.get('{http://www.w3.org/XML/1998/namespace}id')
    
    # Extract forename
    forename = person.find('tei:persName/tei:forename', namespaces=ns)
    person_data['forename'] = forename.text if forename is not None else None
    
    # Extract surname
    surname = person.find('tei:persName/tei:surname', namespaces=ns)
    person_data['surname'] = surname.text if surname is not None else None

    # Extract surname maiden
    surname_maiden = person.find('tei:persName/tei:surname[@type="maiden"]', namespaces=ns)
    person_data['surname maiden']= surname_maiden.text if surname_maiden is not None else None
    
    # Extract occupations (can be multiple)
    occupations = person.findall('tei:occupation', namespaces=ns)
    occupation_data = []
    for occ in occupations:
        # Get the main text of the occupation
        occ_text = occ.text.strip() if occ.text else ""
        
        # Check for nested <orgName> elements
        org_name = occ.find('tei:orgName', namespaces=ns)
        if org_name is not None:
            org_name_text = org_name.text.strip() if org_name.text else ""
            # Combine the occupation text with the organization name
            occ_text += f" {org_name_text}"
        # Add the processed occupation to the list
        occupation_data.append(occ_text)
        # Join all occupations into a single string
        person_data['occupations'] = "; ".join(occupation_data)

    # Extract affiliations (can be multiple)
    affiliations = person.findall('tei:affiliation', namespaces=ns)
    affiliation_data = []
    for affiliation in affiliations:
        # Extract type and subtype attributes
        aff_type = affiliation.get('type')
        aff_subtype = affiliation.get('subtype')
        
        # Extract orgName content and ref attribute
        org_name = affiliation.find('tei:orgName', namespaces=ns)
        org_name_text = org_name.text if org_name is not None else None
        org_name_ref = org_name.get('ref') if org_name is not None else None
        
        # Combine affiliation information into a string
        affiliation_info = f"type: {aff_type}, subtype: {aff_subtype}, orgName: {org_name_text}, ref: {org_name_ref}"
        affiliation_data.append(affiliation_info)
    
    # Join all affiliations into a single string (or store as a list if preferred)
    person_data['affiliations'] = "; ".join(affiliation_data)
    
    # Extract death date and description
    death = person.find('tei:death', namespaces=ns)
    person_data['death_date'] = death.get('when') if death is not None else None
    
    # Extract idno (can be multiple)
    idnos = person.findall('tei:idno', namespaces=ns)
    person_data['idnos'] = "; ".join([f"{idno.get('type')} ({idno.get('subtype')}): {idno.text}" for idno in idnos if idno.text])
    
    # Append the person's data to the list
    data.append(person_data)

# Convert to pandas DataFrame
df_person = pd.DataFrame(data)
df_person= df_person.fillna("")

# Save to a CSV file
df_person.to_csv("C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/csv/person_index.csv", index=False)

# Display the DataFrame
print(df_person)
# Out:
# Number of <person> elements found: 74
#                ID  forename                 surname surname maiden  \
# 0   LudwigLobmeyr    Ludwig                 Lobmeyr
# 1   JosephLobmeyr    Joseph                 Lobmeyr
# 2    FranzLobmeyr     Franz                 Lobmeyr
# 3    LouiseKralik    Louise  Kralik von Meyrswalden        Lobmayr
# 4     HannsKralik     Hanns  Kralik von Meyrswalden
# ..            ...       ...                     ...            ...
# 69   ErnstDohnany     Ernst            von Dohnányi
# 70      Beethoven    Ludwig           van Beethoven
# 71         Mozart  Wolfgang                  Mozart
# 72          Haydn    Joseph                   Haydn
# 73        LeoXIII       Leo                    XIII
#
#                        occupations  \
# 0             k. k. Hofglashändler
# 1             k. k. Hofglashändler
# 2   k. k. Linienschiffs-Lieutenant
# 3
# 4
# ..                             ...
# 69
# 70
# 71
# 72
# 73
#
#                                          affiliations  death_date  \
# 0   type: member, subtype: honorary, orgName: Öste...  1917-03-25
# 1
# 2
# 3                                                      1905-10-03
# 4
# ..                                                ...         ...
# 69
# 70
# 71
# 72
# 73
#
#                                                 idnos
# 0                            ID (WIKIDATA): Q55847850
# 1
# 2
# 3                           ID (WIKIDATA): Q133874636
# 4
# ..                                                ...
# 69  URI (GND): https://d-nb.info/gnd/119110016; ID...
# 70  URI (GND): https://d-nb.info/gnd/118508288; ID...
# 71  URI (GND): https://d-nb.info/gnd/118584596; ID...
# 72  URI (GND): https://d-nb.info/gnd/118547356; ID...
# 73                              ID (WIKIDATA): Q43922
#
# [74 rows x 8 columns]

# %% [markdown]
# ## **2.2. Index place**

# %%
# Extract <place> elements
places = root.xpath('//tei:listPlace/tei:place', namespaces=ns)
print(f"Number of <place> elements found: {len(places)}")

# Extract data
data_place = []
for place in places:
    place_data = {}
    # Extract xml:id
    place_data['ID'] = place.get('{http://www.w3.org/XML/1998/namespace}id')
    
    # Extract placeName
    placename = place.find('tei:placeName', namespaces=ns)
    place_data['name'] = placename.text if placename is not None else None

    #Extract type placeName
    placename_ref=placename.get('type') if placename is not None else None
    place_data['type'] = f"{placename_ref}" if placename is not None else None
    
    # Extract geo
    geo = place.find('tei:location/tei:geo', namespaces=ns)
    place_data['geo'] = geo.text if geo is not None else None
    
    # Extract idno (can be multiple)
    idnos = place.findall('tei:idno', namespaces=ns)
    place_data['idnos'] = "; ".join([f"{idno.get('type')} ({idno.get('subtype')}): {idno.text}" for idno in idnos if idno.text])
    
    # Append the data to the list
    data_place.append(place_data)

# Convert to pandas DataFrame
df_place = pd.DataFrame(data_place)

# Save to a CSV file
df_place.to_csv("C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/csv/place_index.csv", index=False)

# Display the DataFrame
print(df_place)
# Out:
# Number of <place> elements found: 28
#                          ID  \
# 0                      Wien
# 1           Weimarerplatz_3
# 2         DöblingerFriedhof
# 3           WähringerKirche
# 4        Rosensteingasse_32
# 5   HernalserHauptstraße_81
# 6           EhrengrabKralik
# 7               Stephansdom
# 8          StMarxerFriedhof
# 9                    Weimar
# 10          Zentralfriedhof
# 11          GoldeggGasse_19
# 12       Favoritenstraße_27
# 13              Vorderbrühl
# 14        Elisabethstraße_1
# 15        Augustinerkircher
# 16        KärntnerStraße_21
# 17               Rennweg_91
# 18          ErdbergerKirche
# 19            KircheMödling
# 20            Eleonorenhain
# 21                 Annathal
# 22   Zentralfriedhof_Halle1
# 23        WeimarerStraße_89
# 24            Bendlgasse_24
# 25                   Berlin
# 26               Seccession
# 27                     Linz
#
#                                                  name      type  \
# 0                                                Wien      city
# 1                                     Weimarerplatz 3    street
# 2                                  Döblinger Friedhof  cemetery
# 3   Pfarrkirche heilige Gertraud und heiliger\n   ...    church
# 4                                  Rosensteingasse 32    street
# 5                            Hernalser Hauptstraße 81    street
# 6                            Ehrengrab Richard Kralik  cemetery
# 7          Dom- und Metropolitankirche zu St. Stephan    church
# 8                                 St. Marxer Friedhof  cemetery
# 9                                              Weimar      city
# 10                                    Zentralfriedhof  cemetery
# 11                                   Goldegg-Gasse 19    street
# 12                                 Favoritenstraße 27    street
# 13                                        Vorderbrühl   village
# 14                                  Elisabethstraße 1    street
# 15                                   Augustinerkirche    church
# 16                                 Kärntner Straße 21    street
# 17                                         Rennweg 91    street
# 18                              Peter-und-Paul-Kirche    church
# 19                           Stadtpfarrkirche Mödling    church
# 20                                      Eleonorenhain   village
# 21                                           Annathal   village
# 22                      Zentralfriedhof Halle 1 Tor 2  cemetery
# 23                                 Weimarer Straße 89    street
# 24                                      Bendlgasse 24    street
# 25                                             Berlin      city
# 26                                         Seccession    museum
# 27                                               Linz      city
#
#                                        geo  \
# 0                       48.20849, 16.37208
# 1   48.233902622021546, 16.344070193512067
# 2   48.238719731402156, 16.328673269061063
# 3     48.22621692059329, 16.34450228069556
# 4    48.21808403776477, 16.326086765349057
# 5    48.21845628508243, 16.328900153713658
# 6                                     None
# 7    48.20854411963058, 16.373480666951327
# 8      48.18402446536315, 16.4032053383651
# 9                        50.9803, 11.32903
# 10    48.1514660511102, 16.438521926727077
# 11    48.18976066981652, 16.37695638069264
# 12  48.189747763641684, 16.372364634655163
# 13                      48.08284, 16.25874
# 14  48.201765590654134, 16.368675138366534
# 15   48.20610677964904, 16.367669853712695
# 16  48.206327276134346, 16.371738011385606
# 17   48.19044582541425, 16.397931765346893
# 18  48.200857294744246, 16.398227150471623
# 19  48.085662256259745, 16.280088723318332
# 20    48.9343471954487, 13.794896645500788
# 21   48.87337398216413, 13.614796312599777
# 22  48.153249181929844, 16.442484911381403
# 23    48.2367713611113, 16.344899553715038
# 24   48.17974233449344, 16.335147009528303
# 25                      52.52437, 13.41053
# 26                      48.20041, 16.36542
# 27                      48.30639, 14.28611
#
#                                                 idnos
# 0   ID (WIKIDATA): Q1741; URI (geonames): https://...
# 1   URL (Wikipedia): https://de.wikipedia.org/wiki...
# 2   URL (Wikipedia): https://de.wikipedia.org/wiki...
# 3   URL (Wikipedia): https://de.wikipedia.org/wiki...
# 4
# 5
# 6
# 7
# 8                ID (WGW): 18057; ID (GND): 4843295-7
# 9                                ID (WIKIDATA): Q3955
# 10  URL (Wikipedia): https://de.wikipedia.org/wiki...
# 11
# 12
# 13  ID (WIKIDATA): Q114048876; ID (PMB): 957; URI ...
# 14
# 15                                    ID (WGW): 28422
# 16
# 17
# 18                                    ID (WGW): 14138
# 19
# 20
# 21
# 22  URL (Wikipedia): https://de.wikipedia.org/wiki...
# 23
# 24
# 25  ID (WIKIDATA): Q1741; URI (geonames): https://...
# 26  ID (WIKIDATA): Q265129; URL (geonames): https:...
# 27  ID (WIKIDATA): Q41329; URI (geonames): https:/...

# %% [markdown]
# ## **2.3. Index organisation**

# %%
# Extract <org> elements
orgs = root.xpath('//tei:listOrg/tei:org', namespaces=ns)
print(f"Number of <org> elements found: {len(orgs)}")

# Extract data
data_org = []
for org in orgs:
    org_data = {}
    # Extract xml:id
    org_data['ID'] = org.get('{http://www.w3.org/XML/1998/namespace}id')
    
    # Extract orgName
    orgname = org.find('tei:orgName', namespaces=ns)
    org_data['name'] = orgname.text if orgname is not None else f""
    
    # Extract idno (can be multiple)
    idnos = org.findall('tei:idno', namespaces=ns)
    org_data['idnos'] = "; ".join([f"{idno.get('type')} ({idno.get('subtype')}): {idno.text}" for idno in idnos if idno.text])
    
    # Append the data to the list
    data_org.append(org_data)

# Convert to pandas DataFrame
df_org = pd.DataFrame(data_org)

# Save to a CSV file
df_org.to_csv("C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/csv/org_index.csv", index=False)

# Display the DataFrame
print(df_org)
# Out:
# Number of <org> elements found: 22
#                              ID  \
# 0                     JLLobmeyr
# 1                        Gerold
# 2                    Herrenhaus
# 3                        AkBild
# 4        GenossenschaftKünstler
# 5              Schillerstiftung
# 6                 TheyerHartmut
# 7   StädtischeLeichenbestattung
# 8                    DruckBileg
# 9    GeneralinspektionEisenbahn
# 10                Statthalterei
# 11           Enterprisefunebres
# 12                   Bärenhöhle
# 13                     Nordbahn
# 14         EisenbahnMinisterium
# 15              BestattungPayer
# 16                     Lischkar
# 17                    Vaterland
# 18                  FreiePresse
# 19                   Extrablatt
# 20                   MeyrsNeffe
# 21         WienerKonservatorium
#
#                                                  name  \
# 0                                    J. & L. Lobmeyr
# 1                                         Gerold & Co
# 2                                          Herrenhaus
# 3                       Akademie der bildenden Künste
# 4         Genossenschaft der bildenden Künstler Wiens
# 5                           Deutsche Schillerstiftung
# 6                                  THEYER & HARDTMUTH
# 7                        Städtische Leichenbestattung
# 8                                         Josef Bileg
# 9   Generalinspektion der österreichischen Eisenba...
# 10                      Küstenländische Statthalterei
# 11                     Entreprise des pompes funèbres
# 12                                         Bärenhöhle
# 13                         Kaiser-Ferdinands-Nordbahn
# 14                            Eisenbahnen-Ministerium
# 15                              Payer, Schmutzer & Co
# 16                                      Lischkar & Co
# 17                                          Vaterland
# 18                                  Neue Freie Presse
# 19                     Illustrirtes Wiener Extrablatt
# 20                                       Meyr's Neffe
# 21                              Wiener Konservatorium
#
#                                                 idnos
# 0             ID (WGW): 17959; ID (WIKIDATA): Q876883
# 1                                     ID (WGW): 19514
# 2                                     ID (WGW): 12008
# 3   ID (WGW): 17555; ID (GND): 2003761-2; ID (WIKI...
# 4   ID (WGW): 25052; ID (GND): 2100204-6; ID (WIKI...
# 5                                 ID (GND): 5187203-1
# 6                                     ID (WGW): 46454
# 7
# 8
# 9
# 10
# 11
# 12                                    ID (WGW): 42579
# 13  URL (Wikipedia): https://de.wikipedia.org/wiki...
# 14  URL (Wikipedia): https://de.wikipedia.org/wiki...
# 15
# 16
# 17                          ID (WIKIDATA): Q125847075
# 18                            ID (WIKIDATA): Q2919142
# 19                            ID (WIKIDATA): Q1658926
# 20                            ID (WIKIDATA): Q1926388
# 21                           ID (WIKIDATA): Q28864370

# %% [markdown]
# ## **2.4. Index relationships**

# %%
#Created with the help of u:ai
# Extract <relation> elements
relations = root.xpath('//tei:listRelation/tei:relation', namespaces=ns)

# Extract data
relation_data = []
for relation in relations:
    relation_entry = {}
    # Extract relation name
    relation_entry['name'] = relation.get('name')
    
    # Extract active attribute
    relation_entry['active'] = relation.get('active')
    
    # Extract passive attribute
    relation_entry['passive'] = relation.get('passive')
    
    # Extract mutual attribute
    relation_entry['mutual'] = relation.get('mutual')
    
    # Append the relation entry to the list
    relation_data.append(relation_entry)

# Convert to pandas DataFrame
df_relations = pd.DataFrame(relation_data)

# Save to a CSV file (optional)
df_relations.to_csv("C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/csv/relation_index.csv", index=False)


# Display the DataFrame
print(df_relations)
# Out:
#            name           active  \
# 0        parent      #AugustRath
# 1        parent  #AloisiaLobmeyr
# 2        parent    #LouiseKralik
# 3        parent      #MaiaKralik
# 4        parent   #RichardKralik
# 5        parent  #AloisiaPichler
# 6        parent   #EduardPichler
# 7        parent   #RichardKralik
# 8        parent      #MaiaKralik
# 9   grandparent    #LouiseKralik
# 10  grandparent      #MaiaKralik
# 11  grandparent   #RichardKralik
# 12      sibling             None
# 13      sibling             None
# 14      sibling             None
# 15      sibling             None
# 16      sibling             None
# 17      sibling             None
# 18      sibling             None
# 19        uncle   #LudwigLobmeyr
# 20        uncle    #LudwigKralik
# 21       spouse             None
# 22       spouse             None
# 23       spouse             None
# 24       spouse             None
# 25      partner             None
#
#                                               passive  \
# 0   #MarieSchönvonKreuzenau #AugustRathjun #PaulRa...
# 1   #JosephLobmeyr #LudwigLobmeyr #FranzLobmeyr #L...
# 2      #RichardKralik #MathildeKralik #AloisiaPichler
# 3      #DietrichKralik #HeinrichKralik #RodrichKralik
# 4      #DietrichKralik #HeinrichKralik #RodrichKralik
# 5                          #IlsePichler #EdithPichler
# 6                          #IlsePichler #EdithPichler
# 7      #HeinrichKralik #DietrichKralik #RodrichKralik
# 8      #HeinrichKralik #DietrichKralik #RodrichKralik
# 9   #DietrichKralik #HeinrichKralik #RodrichKralik...
# 10     #WinifredKralik #LeopoldKralik #ElfriedeKralik
# 11     #WinifredKralik #LeopoldKralik #ElfriedeKralik
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19  #RudolfLobmeyr #AdolfLobmeyr #OskarLobmeyr #Lu...
# 20  #DietrichKralik #HeinrichKralik #RodrichKralik...
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
#
#                                                mutual
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12         #LouiseKralik #LudwigLobmeyr #MathildeRath
# 13  #RudolfLobmeyr #AdolfLobmeyr #OskarLobmeyr #Lu...
# 14  #MarieSchönvonKreuzenau #AugustRathjun #PaulRa...
# 15     #RichardKralik #MathildeKralik #AloisiaPichler
# 16  #JosephLobmeyr #LudwigLobmeyr #FranzLobmeyr #L...
# 17     #HeinrichKralik #RodrichKralik #DietrichKralik
# 18     #RichardKralik #AloisiaPichler #MathildeKralik
# 19                                               None
# 20                                               None
# 21                       #LouiseKralik #WilhelmKralik
# 22                    #HildegardLobmeyr #FranzLobmeyr
# 23                         #MaiaKralik #RichardKralik
# 24                     #AloisiaPichler #EduardPichler
# 25                    #AliceScarlates #MathildeKralik

# %% [markdown]
# # **3. Converting csv to json**

# %% [markdown]
# ## **3.1. json-person**

# %%
#CODE FOR JSON WITH EMPTY LINES
# Function to clean and preprocess data
#Created with u:ai
def preprocess_value(value):
    """
    Cleans and preprocesses a value:
    - Strips leading/trailing whitespace
    - Replaces empty strings or invalid data with None
    """
    if pd.isna(value) or str(value).strip() == '':
        return f""
    return str(value).strip()

# Apply preprocessing to all cells in the DataFrame
df_person = df_person.applymap(preprocess_value)

# Function to parse complex fields (e.g., affiliations)
def parse_affiliations(affiliations):
    """
    Parses the 'affiliations' field into a structured list of dictionaries.
    """
    if not affiliations:
        return None
    # Split affiliations by tab or newline
    entries = re.split(r'\t|\n', affiliations)
    parsed_entries = []
    for entry in entries:
        # Extract key-value pairs from the entry
        match = re.match(r'type:\s*(.*?),\s*subtype:\s*(.*?),\s*orgName:\s*(.*?),\s*ref:\s*(.*)', entry)
        if match:
            parsed_entries.append({
                "type": match.group(1).strip(),
                "subtype": match.group(2).strip(),
                "orgName": match.group(3).strip(),
                "ref": match.group(4).strip()
            })
    return parsed_entries if parsed_entries else None

# Apply the parsing function to the 'affiliations' column
if 'affiliations' in df_person.columns:
    df_person['affiliations'] = df_person['affiliations'].apply(parse_affiliations)

# Function to remove keys with None values
def remove_null_values(record):
    """
    Removes keys with None values from a dictionary.
    """
    return {key: value for key, value in record.items() if value is not None}

# Convert the DataFrame to a list of dictionaries and remove null values
person_records = [remove_null_values(record) for record in df_person.to_dict(orient='records')]

# Wrap the list of person records in a dictionary with a "data" key
person_json_data = {
    "data": person_records
}

# Write the JSON to a file
output_file_path = 'C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/json/person_index.json'
with open(output_file_path, 'w', encoding='utf-8') as json_file:
    json.dump(person_json_data, json_file, indent=4, ensure_ascii=False)

# Display the JSON structure (optional, for debugging)
print(json.dumps(person_json_data, indent=4, ensure_ascii=False))
# Out:
# {
#     "data": [
#         {
#             "ID": "LudwigLobmeyr",
#             "forename": "Ludwig",
#             "surname": "Lobmeyr",
#             "surname maiden": "",
#             "occupations": "k. k. Hofglashändler",
#             "death_date": "1917-03-25",
#             "idnos": "ID (WIKIDATA): Q55847850"
#         },
#         {
#             "ID": "JosephLobmeyr",
#             "forename": "Joseph",
#             "surname": "Lobmeyr",
#             "surname maiden": "",
#             "occupations": "k. k. Hofglashändler",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "FranzLobmeyr",
#             "forename": "Franz",
#             "surname": "Lobmeyr",
#             "surname maiden": "",
#             "occupations": "k. k. Linienschiffs-Lieutenant",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "LouiseKralik",
#             "forename": "Louise",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "Lobmayr",
#             "occupations": "",
#             "death_date": "1905-10-03",
#             "idnos": "ID (WIKIDATA): Q133874636"
#         },
#         {
#             "ID": "HannsKralik",
#             "forename": "Hanns",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "HeinrichKralikSen",
#             "forename": "Heinrich",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "Glasfabrikant",
#             "death_date": "",
#             "idnos": "URL (Wikipedia): https://de.wikipedia.org/wiki/Heinrich_Kralik_von_Meyrswalden_(Industrieller)"
#         },
#         {
#             "ID": "MathildeRath",
#             "forename": "Mathilde",
#             "surname": "Rath",
#             "surname maiden": "Lobmeyr",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "WilhelmKralik",
#             "forename": "Wilhelm",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "Glasfabriken-Besitzer",
#             "death_date": "",
#             "idnos": "ID (GND): 136539696; ID (WIKIDATA): Q2573745"
#         },
#         {
#             "ID": "LudwigKralik",
#             "forename": "Ludwig",
#             "surname": "Ritter Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "Oberingenieur der Kaiser-Ferdinand-Nordbahn",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "HildegardLobmeyr",
#             "forename": "Hildegard",
#             "surname": "Lobmeyr",
#             "surname maiden": "von Stahlberg",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "AloisiaLobmeyr",
#             "forename": "Aloisia",
#             "surname": "Lobmeyr",
#             "surname maiden": "Dobratsky",
#             "occupations": "",
#             "death_date": "1864-01-26",
#             "idnos": ""
#         },
#         {
#             "ID": "CarlGerold",
#             "forename": "Carl",
#             "surname": "Gerold",
#             "surname maiden": "",
#             "occupations": "Buchdrucker",
#             "death_date": "",
#             "idnos": "ID (WGW): 19487; ID (GND): 133262871; ID (WIKIDATA): Q61995654"
#         },
#         {
#             "ID": "RudolfLobmeyr",
#             "forename": "Rudolf",
#             "surname": "Lobmeyr",
#             "surname maiden": "",
#             "occupations": "k. k. Bezirkshauptmann",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "AdolfLobmeyr",
#             "forename": "Adolf",
#             "surname": "Lobmeyr",
#             "surname maiden": "",
#             "occupations": "Oberinspektionsrat der Generalinspektion der österreichischen Eisenbahnen",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "OskarLobmeyr",
#             "forename": "Oskar",
#             "surname": "von Lobmeyr",
#             "surname maiden": "",
#             "occupations": "Vize-Präsident der küstenländischen Statthalterei",
#             "death_date": "",
#             "idnos": "ID (GND): 1157623174"
#         },
#         {
#             "ID": "LudwigLobmeyrJun",
#             "forename": "Ludwig",
#             "surname": "Lobmeyr",
#             "surname maiden": "",
#             "occupations": "k. k. Rittmeister",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "JennyLobmeyr",
#             "forename": "Jenny",
#             "surname": "Lobmeyr",
#             "surname maiden": "Ruße",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "MarieLobmeyr",
#             "forename": "Marie",
#             "surname": "Lobmeyr",
#             "surname maiden": "Steinhuber",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "EllyLobmeyr",
#             "forename": "Elly",
#             "surname": "von Lobmeyr",
#             "surname maiden": "Arbeßer von Rastburg",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "GretlLobmeyr",
#             "forename": "Gretl",
#             "surname": "Lobmeyr",
#             "surname maiden": "Handofsky",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "HermannSpaun",
#             "forename": "Hermann",
#             "surname": "von Spaun",
#             "surname maiden": "",
#             "occupations": "Geheimer Rat; k. k. Admiral",
#             "death_date": "",
#             "idnos": "ID (GND): 103544075X; URL (ÖBL): https://www.biographien.ac.at/oebl/oebl_S/Spaun_Hermann_1833_1919.xml"
#         },
#         {
#             "ID": "AugustRath",
#             "forename": "August",
#             "surname": "Rath",
#             "surname maiden": "",
#             "occupations": "kaiserlicher Rat",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "MarieSchönvonKreuzenau",
#             "forename": "Marie",
#             "surname": "Schön von Kreuzenau",
#             "surname maiden": "Rath",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "AugustRathjun",
#             "forename": "August",
#             "surname": "Rath jun.",
#             "surname maiden": "",
#             "occupations": "Großindustrieller",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "PaulRath",
#             "forename": "Paul",
#             "surname": "Rath",
#             "surname maiden": "",
#             "occupations": "k.k. Oberst",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "StefanRath",
#             "forename": "Stefan",
#             "surname": "Rath",
#             "surname maiden": "",
#             "occupations": "k. k. Oberleutnant i. V. d. E.; Gesellschafter der Firma J. & L. Lobmeyr",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "AdeleRath",
#             "forename": "Adele",
#             "surname": "Rath",
#             "surname maiden": "Wagenmann",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "KarlPichler",
#             "forename": "Karl",
#             "surname": "Pichler von Deeben",
#             "surname maiden": "",
#             "occupations": "k. k. Ministerialrat",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "MathildeKralik",
#             "forename": "Mathilde",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "Komponistin",
#             "death_date": "",
#             "idnos": "ID (WGW): 37789; ID (WIKIDATA): Q89972; ID (GND): 130214566; ID (PMB): 19659"
#         },
#         {
#             "ID": "AloisiaPichler",
#             "forename": "Louisa",
#             "surname": "Pichler von Deeben",
#             "surname maiden": "Kralik von Meyrswalden",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "MinnaKralik",
#             "forename": "Minna",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "RichardKralik",
#             "forename": "Richard",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "1934-02-04",
#             "idnos": "ID (GND): 118777920; ID (WIKIDATA): Q1317482; ID (WGW): 16425; ID (PMB): 3731"
#         },
#         {
#             "ID": "MaiaKralik",
#             "forename": "Maia",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "von Flattich",
#             "occupations": "",
#             "death_date": "",
#             "idnos": "ID (GND): 116385863"
#         },
#         {
#             "ID": "EduardPichler",
#             "forename": "Eduard",
#             "surname": "Pichler von Deeben",
#             "surname maiden": "",
#             "occupations": "k. k. Ministerialrat; Sektionsrat im Eisenbahn-Ministerium",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "JosefBileg",
#             "forename": "Josef",
#             "surname": "Bileg",
#             "surname maiden": "",
#             "occupations": "Drucker",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "AgnesKralik",
#             "forename": "Agnes",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "EduardSchmid",
#             "forename": "Eduard",
#             "surname": "Schmid",
#             "surname maiden": "",
#             "occupations": "Glasfabrikant",
#             "death_date": "",
#             "idnos": "URL (ÖBL): https://www.biographien.ac.at/oebl/oebl_S/Schmid_Josef-Eduard_1836_1910.xml; ID (GND): 1030547009"
#         },
#         {
#             "ID": "CarlKralik",
#             "forename": "Carl",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "JosefTaschek",
#             "forename": "Josef",
#             "surname": "Taschek",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": "ID (WIKIDATA): Q8311993; URL (Wikipedia): https://de.wikipedia.org/wiki/Josef_Taschek"
#         },
#         {
#             "ID": "DietrichKralik",
#             "forename": "Dietrich",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "Universitätsprofessor",
#             "death_date": "",
#             "idnos": "ID (GND): 118777912; ID (WIKIDATA): Q1223897; ID (WGW): 16414"
#         },
#         {
#             "ID": "HeinrichKralik",
#             "forename": "Heinrich",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": "ID (GND): 121829324; ID (WIKIDATA): Q1235353; ID (WGW): 16424"
#         },
#         {
#             "ID": "RodrichKralik",
#             "forename": "Rodrich",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "Landesgerichtsrat",
#             "death_date": "",
#             "idnos": "ID (GND): 11638610X"
#         },
#         {
#             "ID": "EdithPichler",
#             "forename": "Edith",
#             "surname": "Pichler von Deeben",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "IlsePichler",
#             "forename": "Ilse",
#             "surname": "Pichler von Deeben",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "HannahKralik",
#             "forename": "Hannah",
#             "surname": "Kralik von Meyerswalden",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "GretlKralik",
#             "forename": "Gretl",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "LuiseKralik",
#             "forename": "Luise",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "WinifredKralik",
#             "forename": "Winifred",
#             "surname": "Kralik",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": "ID (WGW): 37795; ID (WIKIDATA): Q59653649; ID (GND): 118643274"
#         },
#         {
#             "ID": "LeopoldKralik",
#             "forename": "Leopold",
#             "surname": "Kralik",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "ElfriedeKralik",
#             "forename": "Elfriede",
#             "surname": "Kralik",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "TheodorInnitzer",
#             "forename": "Theodor",
#             "surname": "Innitzer",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": "ID (GND): 118555634; ID (WIKIDATA): Q78988; ID (WGW): 13273; ID (PMB): 57443"
#         },
#         {
#             "ID": "RudolfWieser",
#             "forename": "Rudolf",
#             "surname": "Wieser",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "EdmundSteinbock",
#             "forename": "Edmund",
#             "surname": "Steinbock",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "AliceScarlates",
#             "forename": "Alice",
#             "surname": "Scarlates",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": "ID (WIKIDATA): Q52084077; ID (GND): 1228633460"
#         },
#         {
#             "ID": "EduardHauptmann",
#             "forename": "Eduard",
#             "surname": "Hauptmann",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "CarlHertlein",
#             "forename": "Carl",
#             "surname": "Hertlein",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "JuliusEpstein",
#             "forename": "Julius",
#             "surname": "Epstein",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": "URI (GND): https://d-nb.info/gnd/116652357; ID (WIKIDATA): Q79036"
#         },
#         {
#             "ID": "IreneZoepf",
#             "forename": "Irene",
#             "surname": "Zoepf",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": "URI (VIAF): http://viaf.org/viaf/66893083"
#         },
#         {
#             "ID": "Herder",
#             "forename": "Johann",
#             "surname": "Herder",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": "ID (WIKIDATA): Q155547; URI (GND): https://d-nb.info/gnd/118549553"
#         },
#         {
#             "ID": "Catull",
#             "forename": "Catull",
#             "surname": "",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": "URI (GND): https://d-nb.info/gnd/118519719; ID (WIKIDATA): Q163079"
#         },
#         {
#             "ID": "JohannRathausky",
#             "forename": "Johann",
#             "surname": "Rathausky",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": "URI (GND): https://d-nb.info/gnd/1027435025"
#         },
#         {
#             "ID": "Sokrates",
#             "forename": "Sokrates",
#             "surname": "",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": "ID (WIKIDATA): Q913"
#         },
#         {
#             "ID": "Ilse",
#             "forename": "Ilse",
#             "surname": "",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "FranziskaTschampa",
#             "forename": "Franziska",
#             "surname": "Tschampa",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": "URI (GND): https://d-nb.info/gnd/1081510544"
#         },
#         {
#             "ID": "LulaGmeiner",
#             "forename": "Lula",
#             "surname": "Gmeiner",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": "URI (GND): https://d-nb.info/gnd/117212490; ID (WIKIDATA): Q1676668"
#         },
#         {
#             "ID": "FranzNaval",
#             "forename": "Franz",
#             "surname": "Naval",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": "URI (GND): https://d-nb.info/gnd/116266945; ID (WIKIDATA): Q87156"
#         },
#         {
#             "ID": "MarcellaPregi",
#             "forename": "Marcella",
#             "surname": "Pregi",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": "URI (GND): https://d-nb.info/gnd/116281588; ID (WIKIDATA): Q94761060"
#         },
#         {
#             "ID": "Angiline",
#             "forename": "Angiline",
#             "surname": "",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": ""
#         },
#         {
#             "ID": "RudolphFitzner",
#             "forename": "Rudolph",
#             "surname": "Fitzner",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": "URI (GND): https://d-nb.info/gnd/116586540; ID (WIKIDATA): Q7377184"
#         },
#         {
#             "ID": "ErnstDohnany",
#             "forename": "Ernst",
#             "surname": "von Dohnányi",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": "URI (GND): https://d-nb.info/gnd/119110016; ID (WIKIDATA): Q78532"
#         },
#         {
#             "ID": "Beethoven",
#             "forename": "Ludwig",
#             "surname": "van Beethoven",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": "URI (GND): https://d-nb.info/gnd/118508288; ID (WIKIDATA): Q255"
#         },
#         {
#             "ID": "Mozart",
#             "forename": "Wolfgang",
#             "surname": "Mozart",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": "URI (GND): https://d-nb.info/gnd/118584596; ID (WIKIDATA): Q254"
#         },
#         {
#             "ID": "Haydn",
#             "forename": "Joseph",
#             "surname": "Haydn",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": "URI (GND): https://d-nb.info/gnd/118547356; ID (WIKIDATA): Q7349"
#         },
#         {
#             "ID": "LeoXIII",
#             "forename": "Leo",
#             "surname": "XIII",
#             "surname maiden": "",
#             "occupations": "",
#             "death_date": "",
#             "idnos": "ID (WIKIDATA): Q43922"
#         }
#     ]
# }
# C:\Users\annab\AppData\Local\Temp\ipykernel_11136\2656941991.py:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_person = df_person.applymap(preprocess_value)

# %%
#CODE FOR JSON WITH NO EMPTY LINES
# Function to clean and preprocess data
#Created with u:ai
def preprocess_value(value):
    """
    Cleans and preprocesses a value:
    - Strips leading/trailing whitespace
    - Replaces empty strings or invalid data with None
    """
    if pd.isna(value) or str(value).strip() == '':
        return None
    return str(value).strip()

# Apply preprocessing to all cells in the DataFrame
df_person = df_person.applymap(preprocess_value)

# Function to parse complex fields (e.g., affiliations)
def parse_affiliations(affiliations):
    """
    Parses the 'affiliations' field into a structured list of dictionaries.
    """
    if not affiliations:
        return None
    # Split affiliations by tab or newline
    entries = re.split(r'\t|\n', affiliations)
    parsed_entries = []
    for entry in entries:
        # Extract key-value pairs from the entry
        match = re.match(r'type:\s*(.*?),\s*subtype:\s*(.*?),\s*orgName:\s*(.*?),\s*ref:\s*(.*)', entry)
        if match:
            parsed_entries.append({
                "type": match.group(1).strip(),
                "subtype": match.group(2).strip(),
                "orgName": match.group(3).strip(),
                "ref": match.group(4).strip()
            })
    return parsed_entries if parsed_entries else None

# Apply the parsing function to the 'affiliations' column
if 'affiliations' in df_person.columns:
    df_person['affiliations'] = df_person['affiliations'].apply(parse_affiliations)

# Function to remove keys with None values
def remove_null_values(record):
    """
    Removes keys with None values from a dictionary.
    """
    return {key: value for key, value in record.items() if value is not None}

# Convert the DataFrame to a list of dictionaries and remove null values
person_records = [remove_null_values(record) for record in df_person.to_dict(orient='records')]

# Wrap the list of person records in a dictionary with a "data" key
person_json_data = {
    "data": person_records
}

# Write the JSON to a file
output_file_path = 'C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/json/person_index_clean.json'
with open(output_file_path, 'w', encoding='utf-8') as json_file:
    json.dump(person_json_data, json_file, indent=4, ensure_ascii=False)

# Display the JSON structure (optional, for debugging)
print(json.dumps(person_json_data, indent=4, ensure_ascii=False))
# Out:
# {
#     "data": [
#         {
#             "ID": "LudwigLobmeyr",
#             "forename": "Ludwig",
#             "surname": "Lobmeyr",
#             "occupations": "k. k. Hofglashändler",
#             "death_date": "1917-03-25",
#             "idnos": "ID (WIKIDATA): Q55847850"
#         },
#         {
#             "ID": "JosephLobmeyr",
#             "forename": "Joseph",
#             "surname": "Lobmeyr",
#             "occupations": "k. k. Hofglashändler"
#         },
#         {
#             "ID": "FranzLobmeyr",
#             "forename": "Franz",
#             "surname": "Lobmeyr",
#             "occupations": "k. k. Linienschiffs-Lieutenant"
#         },
#         {
#             "ID": "LouiseKralik",
#             "forename": "Louise",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "Lobmayr",
#             "death_date": "1905-10-03",
#             "idnos": "ID (WIKIDATA): Q133874636"
#         },
#         {
#             "ID": "HannsKralik",
#             "forename": "Hanns",
#             "surname": "Kralik von Meyrswalden"
#         },
#         {
#             "ID": "HeinrichKralikSen",
#             "forename": "Heinrich",
#             "surname": "Kralik von Meyrswalden",
#             "occupations": "Glasfabrikant",
#             "idnos": "URL (Wikipedia): https://de.wikipedia.org/wiki/Heinrich_Kralik_von_Meyrswalden_(Industrieller)"
#         },
#         {
#             "ID": "MathildeRath",
#             "forename": "Mathilde",
#             "surname": "Rath",
#             "surname maiden": "Lobmeyr"
#         },
#         {
#             "ID": "WilhelmKralik",
#             "forename": "Wilhelm",
#             "surname": "Kralik von Meyrswalden",
#             "occupations": "Glasfabriken-Besitzer",
#             "idnos": "ID (GND): 136539696; ID (WIKIDATA): Q2573745"
#         },
#         {
#             "ID": "LudwigKralik",
#             "forename": "Ludwig",
#             "surname": "Ritter Kralik von Meyrswalden",
#             "occupations": "Oberingenieur der Kaiser-Ferdinand-Nordbahn"
#         },
#         {
#             "ID": "HildegardLobmeyr",
#             "forename": "Hildegard",
#             "surname": "Lobmeyr",
#             "surname maiden": "von Stahlberg"
#         },
#         {
#             "ID": "AloisiaLobmeyr",
#             "forename": "Aloisia",
#             "surname": "Lobmeyr",
#             "surname maiden": "Dobratsky",
#             "death_date": "1864-01-26"
#         },
#         {
#             "ID": "CarlGerold",
#             "forename": "Carl",
#             "surname": "Gerold",
#             "occupations": "Buchdrucker",
#             "idnos": "ID (WGW): 19487; ID (GND): 133262871; ID (WIKIDATA): Q61995654"
#         },
#         {
#             "ID": "RudolfLobmeyr",
#             "forename": "Rudolf",
#             "surname": "Lobmeyr",
#             "occupations": "k. k. Bezirkshauptmann"
#         },
#         {
#             "ID": "AdolfLobmeyr",
#             "forename": "Adolf",
#             "surname": "Lobmeyr",
#             "occupations": "Oberinspektionsrat der Generalinspektion der österreichischen Eisenbahnen"
#         },
#         {
#             "ID": "OskarLobmeyr",
#             "forename": "Oskar",
#             "surname": "von Lobmeyr",
#             "occupations": "Vize-Präsident der küstenländischen Statthalterei",
#             "idnos": "ID (GND): 1157623174"
#         },
#         {
#             "ID": "LudwigLobmeyrJun",
#             "forename": "Ludwig",
#             "surname": "Lobmeyr",
#             "occupations": "k. k. Rittmeister"
#         },
#         {
#             "ID": "JennyLobmeyr",
#             "forename": "Jenny",
#             "surname": "Lobmeyr",
#             "surname maiden": "Ruße"
#         },
#         {
#             "ID": "MarieLobmeyr",
#             "forename": "Marie",
#             "surname": "Lobmeyr",
#             "surname maiden": "Steinhuber"
#         },
#         {
#             "ID": "EllyLobmeyr",
#             "forename": "Elly",
#             "surname": "von Lobmeyr",
#             "surname maiden": "Arbeßer von Rastburg"
#         },
#         {
#             "ID": "GretlLobmeyr",
#             "forename": "Gretl",
#             "surname": "Lobmeyr",
#             "surname maiden": "Handofsky"
#         },
#         {
#             "ID": "HermannSpaun",
#             "forename": "Hermann",
#             "surname": "von Spaun",
#             "occupations": "Geheimer Rat; k. k. Admiral",
#             "idnos": "ID (GND): 103544075X; URL (ÖBL): https://www.biographien.ac.at/oebl/oebl_S/Spaun_Hermann_1833_1919.xml"
#         },
#         {
#             "ID": "AugustRath",
#             "forename": "August",
#             "surname": "Rath",
#             "occupations": "kaiserlicher Rat"
#         },
#         {
#             "ID": "MarieSchönvonKreuzenau",
#             "forename": "Marie",
#             "surname": "Schön von Kreuzenau",
#             "surname maiden": "Rath"
#         },
#         {
#             "ID": "AugustRathjun",
#             "forename": "August",
#             "surname": "Rath jun.",
#             "occupations": "Großindustrieller"
#         },
#         {
#             "ID": "PaulRath",
#             "forename": "Paul",
#             "surname": "Rath",
#             "occupations": "k.k. Oberst"
#         },
#         {
#             "ID": "StefanRath",
#             "forename": "Stefan",
#             "surname": "Rath",
#             "occupations": "k. k. Oberleutnant i. V. d. E.; Gesellschafter der Firma J. & L. Lobmeyr"
#         },
#         {
#             "ID": "AdeleRath",
#             "forename": "Adele",
#             "surname": "Rath",
#             "surname maiden": "Wagenmann"
#         },
#         {
#             "ID": "KarlPichler",
#             "forename": "Karl",
#             "surname": "Pichler von Deeben",
#             "occupations": "k. k. Ministerialrat"
#         },
#         {
#             "ID": "MathildeKralik",
#             "forename": "Mathilde",
#             "surname": "Kralik von Meyrswalden",
#             "occupations": "Komponistin",
#             "idnos": "ID (WGW): 37789; ID (WIKIDATA): Q89972; ID (GND): 130214566; ID (PMB): 19659"
#         },
#         {
#             "ID": "AloisiaPichler",
#             "forename": "Louisa",
#             "surname": "Pichler von Deeben",
#             "surname maiden": "Kralik von Meyrswalden"
#         },
#         {
#             "ID": "MinnaKralik",
#             "forename": "Minna",
#             "surname": "Kralik von Meyrswalden"
#         },
#         {
#             "ID": "RichardKralik",
#             "forename": "Richard",
#             "surname": "Kralik von Meyrswalden",
#             "death_date": "1934-02-04",
#             "idnos": "ID (GND): 118777920; ID (WIKIDATA): Q1317482; ID (WGW): 16425; ID (PMB): 3731"
#         },
#         {
#             "ID": "MaiaKralik",
#             "forename": "Maia",
#             "surname": "Kralik von Meyrswalden",
#             "surname maiden": "von Flattich",
#             "idnos": "ID (GND): 116385863"
#         },
#         {
#             "ID": "EduardPichler",
#             "forename": "Eduard",
#             "surname": "Pichler von Deeben",
#             "occupations": "k. k. Ministerialrat; Sektionsrat im Eisenbahn-Ministerium"
#         },
#         {
#             "ID": "JosefBileg",
#             "forename": "Josef",
#             "surname": "Bileg",
#             "occupations": "Drucker"
#         },
#         {
#             "ID": "AgnesKralik",
#             "forename": "Agnes",
#             "surname": "Kralik von Meyrswalden"
#         },
#         {
#             "ID": "EduardSchmid",
#             "forename": "Eduard",
#             "surname": "Schmid",
#             "occupations": "Glasfabrikant",
#             "idnos": "URL (ÖBL): https://www.biographien.ac.at/oebl/oebl_S/Schmid_Josef-Eduard_1836_1910.xml; ID (GND): 1030547009"
#         },
#         {
#             "ID": "CarlKralik",
#             "forename": "Carl",
#             "surname": "Kralik von Meyrswalden"
#         },
#         {
#             "ID": "JosefTaschek",
#             "forename": "Josef",
#             "surname": "Taschek",
#             "idnos": "ID (WIKIDATA): Q8311993; URL (Wikipedia): https://de.wikipedia.org/wiki/Josef_Taschek"
#         },
#         {
#             "ID": "DietrichKralik",
#             "forename": "Dietrich",
#             "surname": "Kralik von Meyrswalden",
#             "occupations": "Universitätsprofessor",
#             "idnos": "ID (GND): 118777912; ID (WIKIDATA): Q1223897; ID (WGW): 16414"
#         },
#         {
#             "ID": "HeinrichKralik",
#             "forename": "Heinrich",
#             "surname": "Kralik von Meyrswalden",
#             "idnos": "ID (GND): 121829324; ID (WIKIDATA): Q1235353; ID (WGW): 16424"
#         },
#         {
#             "ID": "RodrichKralik",
#             "forename": "Rodrich",
#             "surname": "Kralik von Meyrswalden",
#             "occupations": "Landesgerichtsrat",
#             "idnos": "ID (GND): 11638610X"
#         },
#         {
#             "ID": "EdithPichler",
#             "forename": "Edith",
#             "surname": "Pichler von Deeben"
#         },
#         {
#             "ID": "IlsePichler",
#             "forename": "Ilse",
#             "surname": "Pichler von Deeben"
#         },
#         {
#             "ID": "HannahKralik",
#             "forename": "Hannah",
#             "surname": "Kralik von Meyerswalden"
#         },
#         {
#             "ID": "GretlKralik",
#             "forename": "Gretl",
#             "surname": "Kralik von Meyrswalden"
#         },
#         {
#             "ID": "LuiseKralik",
#             "forename": "Luise",
#             "surname": "Kralik von Meyrswalden"
#         },
#         {
#             "ID": "WinifredKralik",
#             "forename": "Winifred",
#             "surname": "Kralik",
#             "idnos": "ID (WGW): 37795; ID (WIKIDATA): Q59653649; ID (GND): 118643274"
#         },
#         {
#             "ID": "LeopoldKralik",
#             "forename": "Leopold",
#             "surname": "Kralik"
#         },
#         {
#             "ID": "ElfriedeKralik",
#             "forename": "Elfriede",
#             "surname": "Kralik"
#         },
#         {
#             "ID": "TheodorInnitzer",
#             "forename": "Theodor",
#             "surname": "Innitzer",
#             "idnos": "ID (GND): 118555634; ID (WIKIDATA): Q78988; ID (WGW): 13273; ID (PMB): 57443"
#         },
#         {
#             "ID": "RudolfWieser",
#             "forename": "Rudolf",
#             "surname": "Wieser"
#         },
#         {
#             "ID": "EdmundSteinbock",
#             "forename": "Edmund",
#             "surname": "Steinbock"
#         },
#         {
#             "ID": "AliceScarlates",
#             "forename": "Alice",
#             "surname": "Scarlates",
#             "idnos": "ID (WIKIDATA): Q52084077; ID (GND): 1228633460"
#         },
#         {
#             "ID": "EduardHauptmann",
#             "forename": "Eduard",
#             "surname": "Hauptmann"
#         },
#         {
#             "ID": "CarlHertlein",
#             "forename": "Carl",
#             "surname": "Hertlein"
#         },
#         {
#             "ID": "JuliusEpstein",
#             "forename": "Julius",
#             "surname": "Epstein",
#             "idnos": "URI (GND): https://d-nb.info/gnd/116652357; ID (WIKIDATA): Q79036"
#         },
#         {
#             "ID": "IreneZoepf",
#             "forename": "Irene",
#             "surname": "Zoepf",
#             "idnos": "URI (VIAF): http://viaf.org/viaf/66893083"
#         },
#         {
#             "ID": "Herder",
#             "forename": "Johann",
#             "surname": "Herder",
#             "idnos": "ID (WIKIDATA): Q155547; URI (GND): https://d-nb.info/gnd/118549553"
#         },
#         {
#             "ID": "Catull",
#             "forename": "Catull",
#             "idnos": "URI (GND): https://d-nb.info/gnd/118519719; ID (WIKIDATA): Q163079"
#         },
#         {
#             "ID": "JohannRathausky",
#             "forename": "Johann",
#             "surname": "Rathausky",
#             "idnos": "URI (GND): https://d-nb.info/gnd/1027435025"
#         },
#         {
#             "ID": "Sokrates",
#             "forename": "Sokrates",
#             "idnos": "ID (WIKIDATA): Q913"
#         },
#         {
#             "ID": "Ilse",
#             "forename": "Ilse"
#         },
#         {
#             "ID": "FranziskaTschampa",
#             "forename": "Franziska",
#             "surname": "Tschampa",
#             "idnos": "URI (GND): https://d-nb.info/gnd/1081510544"
#         },
#         {
#             "ID": "LulaGmeiner",
#             "forename": "Lula",
#             "surname": "Gmeiner",
#             "idnos": "URI (GND): https://d-nb.info/gnd/117212490; ID (WIKIDATA): Q1676668"
#         },
#         {
#             "ID": "FranzNaval",
#             "forename": "Franz",
#             "surname": "Naval",
#             "idnos": "URI (GND): https://d-nb.info/gnd/116266945; ID (WIKIDATA): Q87156"
#         },
#         {
#             "ID": "MarcellaPregi",
#             "forename": "Marcella",
#             "surname": "Pregi",
#             "idnos": "URI (GND): https://d-nb.info/gnd/116281588; ID (WIKIDATA): Q94761060"
#         },
#         {
#             "ID": "Angiline",
#             "forename": "Angiline"
#         },
#         {
#             "ID": "RudolphFitzner",
#             "forename": "Rudolph",
#             "surname": "Fitzner",
#             "idnos": "URI (GND): https://d-nb.info/gnd/116586540; ID (WIKIDATA): Q7377184"
#         },
#         {
#             "ID": "ErnstDohnany",
#             "forename": "Ernst",
#             "surname": "von Dohnányi",
#             "idnos": "URI (GND): https://d-nb.info/gnd/119110016; ID (WIKIDATA): Q78532"
#         },
#         {
#             "ID": "Beethoven",
#             "forename": "Ludwig",
#             "surname": "van Beethoven",
#             "idnos": "URI (GND): https://d-nb.info/gnd/118508288; ID (WIKIDATA): Q255"
#         },
#         {
#             "ID": "Mozart",
#             "forename": "Wolfgang",
#             "surname": "Mozart",
#             "idnos": "URI (GND): https://d-nb.info/gnd/118584596; ID (WIKIDATA): Q254"
#         },
#         {
#             "ID": "Haydn",
#             "forename": "Joseph",
#             "surname": "Haydn",
#             "idnos": "URI (GND): https://d-nb.info/gnd/118547356; ID (WIKIDATA): Q7349"
#         },
#         {
#             "ID": "LeoXIII",
#             "forename": "Leo",
#             "surname": "XIII",
#             "idnos": "ID (WIKIDATA): Q43922"
#         }
#     ]
# }
# C:\Users\annab\AppData\Local\Temp\ipykernel_11136\1623254778.py:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_person = df_person.applymap(preprocess_value)

# %%
#df_person to json
person_json=df_person.to_json(orient='records', indent=4)
with open('C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/json/person_index.json', 'w') as json_file:
    json_file.write(person_json)

#df_place to json
place_json=df_place.to_json(orient='records', indent=4)
with open('C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/json/place_index.json', 'w') as json_file:
    json_file.write(place_json)

#df_org to json
org_json=df_org.to_json(orient='records', indent=4)
with open('C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/json/org_index.json', 'w') as json_file:
    json_file.write(org_json)

#df_relation
relation_json=df_relations.to_json(orient='records', indent=4)
with open('C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/json/relation_index.json', 'w') as json_file:
    json_file.write(relation_json)

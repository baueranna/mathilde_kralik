# %% [markdown]
# # **1. Libaries and files**

# %%
#Importing libraries
import os
import glob
import re
from bs4 import BeautifulSoup, Tag, NavigableString
import xml.etree.ElementTree as ET
from xml.dom import minidom
from xml.etree.ElementTree import Element
from xml.etree.ElementTree import SubElement
import pandas as pd
from lxml import etree

# %%
file_path_index="C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/tei/Index/index_person_place_org.xml"

# %% [markdown]
# # **2. Creating csv with index**

# %%
#Accessing index
tree = etree.parse(file_path_index)
root = tree.getroot()

# %%
# Define the TEI namespace
ns = {'tei': 'http://www.tei-c.org/ns/1.0'}

# %% [markdown]
# ## **2.1. Index person**

# %%
#Created with the help of u:ai
# Extract <person> elements
persons = root.xpath('//tei:listPerson/tei:person', namespaces=ns)
print(f"Number of <person> elements found: {len(persons)}")

# Extract data
data = []
for person in persons:
    person_data = {}
    # Extract xml:id
    person_data['ID'] = person.get('{http://www.w3.org/XML/1998/namespace}id')
    
    # Extract forename
    forename = person.find('tei:persName/tei:forename', namespaces=ns)
    person_data['forename'] = forename.text if forename is not None else None
    
    # Extract surname
    surname = person.find('tei:persName/tei:surname', namespaces=ns)
    person_data['surname'] = surname.text if surname is not None else None

    # Extract surname maiden
    surname_maiden = person.find('tei:persName/tei:surname[@type="maiden"]', namespaces=ns)
    person_data['surname maiden']= surname_maiden.text if surname_maiden is not None else None
    
    # Extract occupations (can be multiple)
    occupations = person.findall('tei:occupation', namespaces=ns)
    person_data['occupations'] = "; ".join([occ.text for occ in occupations if occ.text])

    # Extract affiliations (can be multiple)
    affiliations = person.findall('tei:affiliation', namespaces=ns)
    affiliation_data = []
    for affiliation in affiliations:
        # Extract type and subtype attributes
        aff_type = affiliation.get('type')
        aff_subtype = affiliation.get('subtype')
        
        # Extract orgName content and ref attribute
        org_name = affiliation.find('tei:orgName', namespaces=ns)
        org_name_text = org_name.text if org_name is not None else None
        org_name_ref = org_name.get('ref') if org_name is not None else None
        
        # Combine affiliation information into a string
        affiliation_info = f"type: {aff_type}, subtype: {aff_subtype}, orgName: {org_name_text}, ref: {org_name_ref}"
        affiliation_data.append(affiliation_info)
    
    # Join all affiliations into a single string (or store as a list if preferred)
    person_data['affiliations'] = "; ".join(affiliation_data)
    
    # Extract death date and description
    death = person.find('tei:death', namespaces=ns)
    person_data['death_date'] = death.get('when') if death is not None else None
    
    # Extract idno (can be multiple)
    idnos = person.findall('tei:idno', namespaces=ns)
    person_data['idnos'] = "; ".join([f"{idno.get('type')} ({idno.get('subtype')}): {idno.text}" for idno in idnos if idno.text])
    
    # Append the person's data to the list
    data.append(person_data)

# Convert to pandas DataFrame
df_person = pd.DataFrame(data)

# Save to a CSV file (optional)
df_person.to_csv("C:/Users/annab/OneDrive/Desktop/Kralik/mathilde_kralik/data/csv/person_index.csv", index=False)

# Display the DataFrame
print(df_person)
# Out:
# Number of <person> elements found: 54
#                         ID   forename                        surname  \
# 0            LudwigLobmeyr     Ludwig                        Lobmeyr
# 1            JosephLobmeyr     Joseph                        Lobmeyr
# 2             FranzLobmeyr      Franz                        Lobmeyr
# 3             LouiseKralik     Louise         Kralik von Meyrswalden
# 4              HannsKralik      Hanns         Kralik von Meyrswalden
# 5        HeinrichKralikSen   Heinrich         Kralik von Meyrswalden
# 6             MathildeRath   Mathilde                           Rath
# 7            WilhelmKralik    Wilhelm         Kralik von Meyrswalden
# 8             LudwigKralik     Ludwig  Ritter Kralik von Meyrswalden
# 9         HildegardLobmeyr  Hildegard                        Lobmeyr
# 10          AloisiaLobmeyr    Aloisia                        Lobmeyr
# 11              CarlGerold       Carl                         Gerold
# 12           RudolfLobmeyr     Rudolf                        Lobmeyr
# 13            AdolfLobmeyr      Adolf                        Lobmeyr
# 14            OskarLobmeyr      Oskar                    von Lobmeyr
# 15        LudwigLobmeyrJun     Ludwig                        Lobmeyr
# 16            JennyLobmeyr      Jenny                        Lobmeyr
# 17            MarieLobmeyr      Marie                        Lobmeyr
# 18             EllyLobmeyr       Elly                    von Lobmeyr
# 19            GretlLobmeyr      Gretl                        Lobmeyr
# 20            HermannSpaun    Hermann                      von Spaun
# 21              AugustRath     August                           Rath
# 22  MarieSchönvonKreuzenau      Marie            Schön von Kreuzenau
# 23           AugustRathjun     August                      Rath jun.
# 24                PaulRath       Paul                           Rath
# 25              StefanRath     Stefan                           Rath
# 26               AdeleRath      Adele                           Rath
# 27             KarlPichler       Karl             Pichler von Deeben
# 28          MathildeKralik   Mathilde         Kralik von Meyrswalden
# 29          AloisiaPichler     Louisa             Pichler von Deeben
# 30             MinnaKralik      Minna         Kralik von Meyrswalden
# 31           RichardKralik    Richard         Kralik von Meyrswalden
# 32              MaiaKralik       Maia         Kralik von Meyrswalden
# 33           EduardPichler     Eduard             Pichler von Deeben
# 34              JosefBileg      Josef                          Bileg
# 35             AgnesKralik      Agnes         Kralik von Meyrswalden
# 36            EduardSchmid     Eduard                         Schmid
# 37              CarlKralik       Carl         Kralik von Meyrswalden
# 38            JosefTaschek      Josef                        Taschek
# 39          DietrichKralik   Dietrich         Kralik von Meyrswalden
# 40          HeinrichKralik   Heinrich         Kralik von Meyrswalden
# 41           RodrichKralik    Rodrich         Kralik von Meyrswalden
# 42            EdithPichler      Edith             Pichler von Deeben
# 43             IlsePichler       Ilse             Pichler von Deeben
# 44            HannahKralik     Hannah        Kralik von Meyerswalden
# 45             GretlKralik      Gretl         Kralik von Meyrswalden
# 46             LuiseKralik      Luise         Kralik von Meyrswalden
# 47          WinifredKralik   Winifred                         Kralik
# 48           LeopoldKralik    Leopold                         Kralik
# 49          ElfriedeKralik   Elfriede                         Kralik
# 50         TheodorInnitzer    Theodor                       Innitzer
# 51            RudolfWieser     Rudolf                         Wieser
# 52         EdmundSteinbock     Edmund                      Steinbock
# 53          AliceScarlates      Alice                      Scarlates
#
#             surname maiden                                        occupations  \
# 0                     None                               k. k. Hofglashändler
# 1                     None                               k. k. Hofglashändler
# 2                     None                     k. k. Linienschiffs-Lieutenant
# 3                  Lobmayr
# 4                     None
# 5                     None                                      Glasfabrikant
# 6                  Lobmeyr
# 7                     None                              Glasfabriken-Besitzer
# 8                     None                                  Oberingenier der
# 9            von Stahlberg
# 10               Dobratsky
# 11                    None                                        Buchdrucker
# 12                    None                             k. k. Bezirkshauptmann
# 13                    None                            Oberinspektionsrat der
# 14                    None                                Vize-Präsident der
# 15                    None                                  k. k. Rittmeister
# 16                    Ruße
# 17              Steinhuber
# 18    Arbeßer von Rastburg
# 19               Handofsky
# 20                    None                        Geheimer Rat; k. k. Admiral
# 21                    None                                   kaiserlicher Rat
# 22                    Rath
# 23                    None                                  Großindustrieller
# 24                    None                                        k.k. Oberst
# 25                    None  k. k. Oberleutnant i. V. d. E.; Gesellschafter...
# 26               Wagenmann
# 27                    None                               k. k. Ministerialrat
# 28                    None
# 29  Kralik von Meyrswalden
# 30                    None
# 31                    None
# 32            von Flattich
# 33                    None              k. k. Ministerialrat; Sektionsrat im
# 34                    None                                            Drucker
# 35                    None
# 36                    None                                      Glasfabrikant
# 37                    None
# 38                    None
# 39                    None                              Universitätsprofessor
# 40                    None
# 41                    None                                  Landesgerichtsrat
# 42                    None
# 43                    None
# 44                    None
# 45                    None
# 46                    None
# 47                    None
# 48                    None
# 49                    None
# 50                    None
# 51                    None
# 52                    None
# 53                    None
#
#                                          affiliations  death_date  \
# 0   type: member, subtype: honorary, orgName: Öste...  1917-03-25
# 1                                                            None
# 2                                                            None
# 3                                                      1905-10-03
# 4                                                            None
# 5                                                            None
# 6                                                            None
# 7                                                            None
# 8                                                            None
# 9                                                            None
# 10                                                     1864-01-26
# 11  type: owner, subtype: None, orgName: Gerold & ...        None
# 12                                                           None
# 13                                                           None
# 14                                                           None
# 15                                                           None
# 16                                                           None
# 17                                                           None
# 18                                                           None
# 19                                                           None
# 20                                                           None
# 21                                                           None
# 22                                                           None
# 23                                                           None
# 24                                                           None
# 25                                                           None
# 26                                                           None
# 27                                                           None
# 28                                                           None
# 29                                                           None
# 30                                                           None
# 31                                                     1934-02-04
# 32                                                           None
# 33                                                           None
# 34                                                           None
# 35                                                           None
# 36                                                           None
# 37                                                           None
# 38                                                           None
# 39  type: member, subtype: political, orgName: Non...        None
# 40                                                           None
# 41                                                           None
# 42                                                           None
# 43                                                           None
# 44                                                           None
# 45                                                           None
# 46                                                           None
# 47                                                           None
# 48                                                           None
# 49                                                           None
# 50                                                           None
# 51                                                           None
# 52                                                           None
# 53                                                           None
#
#                                                 idnos
# 0                            ID (WIKIDATA): Q55847850
# 1
# 2
# 3                           ID (WIKIDATA): Q133874636
# 4
# 5   URL (Wikipedia): https://de.wikipedia.org/wiki...
# 6
# 7        ID (GND): 136539696; ID (WIKIDATA): Q2573745
# 8
# 9
# 10
# 11  ID (WGW): 19487; ID (GND): 133262871; ID (WIKI...
# 12
# 13
# 14                               ID (GND): 1157623174
# 15
# 16
# 17
# 18
# 19
# 20  ID (GND): 103544075X; URL (ÖBL): https://www.b...
# 21
# 22
# 23
# 24
# 25
# 26
# 27
# 28  ID (WGW): 37789; ID (WIKIDATA): Q89972; ID (GN...
# 29
# 30
# 31  ID (GND): 118777920; ID (WIKIDATA): Q1317482; ...
# 32                                ID (GND): 116385863
# 33
# 34
# 35
# 36  URL (ÖBL): https://www.biographien.ac.at/oebl/...
# 37
# 38  ID (WIKIDATA): Q8311993; URL (Wikipedia): http...
# 39  ID (GND): 118777912; ID (WIKIDATA): Q1223897; ...
# 40  ID (GND): 121829324; ID (WIKIDATA): Q1235353; ...
# 41                                ID (GND): 11638610X
# 42
# 43
# 44
# 45
# 46
# 47  ID (WGW): 37795; ID (WIKIDATA): Q59653649; ID ...
# 48
# 49
# 50  ID (GND): 118555634; ID (WIKIDATA): Q78988; ID...
# 51
# 52
# 53     ID (WIKIDATA): Q52084077; ID (GND): 1228633460
